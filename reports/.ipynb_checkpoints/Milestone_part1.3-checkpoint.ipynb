# %% [markdown]
# # Milestone Report Part 1.3: Train data processing
#
# This file is get the data ready for training the CNN algorithm.
#
# Due to the large amount of data (400GB in total, yeah I know what you are thinking, it is not that large but that is half of my disk already), all input are stored outside of repository folder by name "cap2input". I will have a independent document on how to re-run this on your own computer, with all the data storage explained...
#
# Note that I add a 300 limit to the iteration, meaning that only 300 out of 1400 data samples are selected for the training. The reason for this is running through all 1400 data will take up to 5 days to finish. I simply do not have that much time at this moment. However, in the future I will test this on the whole dataset as well as refining some pre-processing procedure.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import skimage, os
from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from scipy import ndimage as ndi

# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import dicom
import scipy.misc
import numpy as np

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../../cap2input"]).decode("utf8"))
# Out:
# sample_images
# stage1
# stage1_labels.csv
# stage1_sample_submission.csv
# stage1_solution.csv
# stage2
# stage2.7z
# stage2_sample_submission.csv.zip
# stage2_solution.csv

# %%
def read_ct_scan(folder_name):
        # Read the slices from the dicom file
        slices = [dicom.read_file(folder_name + filename) for filename in os.listdir(folder_name)]
        
        # Sort the dicom slices in their respective order
        slices.sort(key=lambda x: int(x.InstanceNumber))
        
        # Get the pixel values for all the slices
        image = np.stack([s.pixel_array for s in slices])
        intercept = int(slices[0].RescaleIntercept)
        image[image <= -1900] = -1000-intercept
        
        for slice_number in range(len(slices)):
        
            intercept = float(slices[slice_number].RescaleIntercept)
            slope = int(slices[slice_number].RescaleSlope)
            
            #print(intercept,slope)
        
            if slope != 1:
                image[slice_number] = slope * image[slice_number].astype(np.float64)
                
            image[slice_number] = image[slice_number].astype(np.int16)
            intercept = np.int16(intercept)

            image[slice_number] += intercept.astype(image[slice_number].dtype)
        print image.dtype
            
        return np.array(image, dtype=np.int16)
    
THRES = -400

def get_segmented_lungs(im, plot=False):
    '''
    This funtion segments the lungs from the given 2D slice.
    '''
    if plot == True:
        f, plots = plt.subplots(8, 1, figsize=(5, 40))
    '''
    Step 1: Convert into a binary image. 
    '''
    binary = im < THRES
    if plot == True:
        plots[0].axis('off')
        plots[0].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 2: Remove the blobs connected to the border of the image.
    '''
    cleared = clear_border(binary)
    if plot == True:
        plots[1].axis('off')
        plots[1].imshow(cleared, cmap=plt.cm.bone) 
    '''
    Step 3: Label the image.
    '''
    label_image = label(cleared)
    if plot == True:
        plots[2].axis('off')
        plots[2].imshow(label_image, cmap=plt.cm.bone) 
    '''
    Step 4: Keep the labels with 2 largest areas.
    '''
    areas = [r.area for r in regionprops(label_image)]
    areas.sort()
    if len(areas) > 2:
        for region in regionprops(label_image):
            if region.area < areas[-2]:
                for coordinates in region.coords:                
                       label_image[coordinates[0], coordinates[1]] = 0
    binary = label_image > 0
    if plot == True:
        plots[3].axis('off')
        plots[3].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 5: Erosion operation with a disk of radius 2. This operation is 
    seperate the lung nodules attached to the blood vessels.
    '''
    selem = disk(2)
    binary = binary_erosion(binary, selem)
    if plot == True:
        plots[4].axis('off')
        plots[4].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 6: Closure operation with a disk of radius 10. This operation is 
    to keep nodules attached to the lung wall.
    '''
    selem = disk(12)
    binary = binary_closing(binary, selem)
    if plot == True:
        plots[5].axis('off')
        plots[5].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 7: Fill in the small holes inside the binary mask of lungs.
    '''
    edges = roberts(binary)
    binary = ndi.binary_fill_holes(edges)
    if plot == True:
        plots[6].axis('off')
        plots[6].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 8: Superimpose the binary mask on the input image.
    '''
    get_high_vals = binary == 0
    im[get_high_vals] = -1000
    if plot == True:
        plots[7].axis('off')
        plots[7].imshow(im, cmap=plt.cm.bone) 
        
    return im

def segment_lung_from_ct_scan(ct_scan):
    return np.asarray([get_segmented_lungs(single_slice) for single_slice in ct_scan])

def plot_ct_scan(scan):
    f, plots = plt.subplots(int(scan.shape[0] / 20) + 1, 4, figsize=(25, 25))
    for i in range(0, scan.shape[0], 5):
        plots[int(i / 20), int((i % 20) / 5)].axis('off')
        plots[int(i / 20), int((i % 20) / 5)].imshow(scan[i], cmap=plt.cm.bone)
        
def plot_3d(image, threshold=-1300):
    
    # Position the scan upright, 
    # so the head of the patient would be at the top facing the camera
    p = image.transpose(2,1,0)
    p = p[:,:,::-1]
    
    verts, faces,_,_ = measure.marching_cubes(p, threshold)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh = Poly3DCollection(verts[faces], alpha=0.1)
    face_color = [0.5, 0.5, 1]
    mesh.set_facecolor(face_color)
    ax.add_collection3d(mesh)

    ax.set_xlim(0, p.shape[0])
    ax.set_ylim(0, p.shape[1])
    ax.set_zlim(0, p.shape[2])

    plt.show()

# %%
from skimage.morphology import opening
import cv2
import math

IMG_SIZE_PX = 50
SLICE_COUNT = 20

def chunks(l, n):
    # Credit: Ned Batchelder
    # Link: http://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunks
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]
        
def mean(a):
    return sum(a) / len(a)

def process_data(patient, labels_df, img_px_size=IMG_SIZE_PX, hm_slices=SLICE_COUNT, vis=False):
    path = data_dir + patient + '/'
    print path
    ct_scan = read_ct_scan(path)
    
    segmented_ct_scan = segment_lung_from_ct_scan(ct_scan)
    segmented_ct_scan[segmented_ct_scan < THRES] = -1000
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!   
#    selem = ball(3) #was 2
#    segmented_ct_scan = opening(segmented_ct_scan, selem)
    
    if vis == True:
        plot_3d(segmented_ct_scan, THRES)
        print(segmented_ct_scan[0].shape, len(segmented_ct_scan))
        
    slices_b = segmented_ct_scan
    new_slices = []
    slices_b = [cv2.resize(np.array(each_slice),(img_px_size,img_px_size)) for each_slice in slices_b]
    
    chunk_sizes = int(math.ceil(len(slices_b) / hm_slices))
    for slice_chunk in chunks(slices_b, chunk_sizes):
        slice_chunk = list(map(mean, zip(*slice_chunk)))
        new_slices.append(slice_chunk)
    
    while (len(new_slices) < hm_slices):
        new_slices.append(new_slices[-1])
        
    while (len(new_slices) > hm_slices):
        new_val = list(map(mean, zip(*[new_slices[hm_slices-1],new_slices[hm_slices],])))
        del new_slices[hm_slices]
        new_slices[hm_slices-1] = new_val
    
    label_b = labels_df.get_value(patient, 'cancer')

    if label_b == 1: label_b=np.array([0,1])
    elif label_b == 0: label_b=np.array([1,0])
        
    if vis == True:
        print(patient, label_b)
    print(len(slices_b), len(new_slices))
        
    return np.array(new_slices),label_b


data_dir = '../../cap2input/stage1/'
patients = os.listdir(data_dir)
#patient = 'ea7373271a2441b5864df2053c0f5c3e'
labels = pd.read_csv('../../cap2input/stage1_labels.csv', index_col=0)

much_data = []
limit = 300
for num,patient in enumerate(patients):
    if num > limit:
        break
    if num % 100 == 0:
        print(num)
    try:
        img_data,label_c = process_data(patient,labels,img_px_size=IMG_SIZE_PX, hm_slices=SLICE_COUNT)
        #print(img_data.shape,label)
        much_data.append([img_data,label_c,patient])
    except KeyError as e:
        print('This is unlabeled data!')

np.save('../../cap2input/output/muchdata-{}-{}-{}-b.npy'.format(IMG_SIZE_PX,IMG_SIZE_PX,SLICE_COUNT), much_data)

#process_data(patient, labels, vis = True)
# Out:
# 0
# ../../cap2input/stage1/eba18d04b18084ef64be8f22bb7905ca/
# int16
# /home/zexi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:50: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# (281, 20)
# ../../cap2input/stage1/3457880b1a66030feb8adaed6da805af/
# uint16
# (472, 20)
# ../../cap2input/stage1/14248ec22193bed1e087755df5a28509/
# int16
# (224, 20)
# ../../cap2input/stage1/668bb968918c63fad7d65581825b1048/
# uint16
# (185, 20)
# ../../cap2input/stage1/9a378249b799bbcefac2a7de46896c0a/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/440fb90654b1436e7c3bbdac991b8c1d/
# int16
# (158, 20)
# ../../cap2input/stage1/96acca47671874c41de6023942e10c16/
# uint16
# (197, 20)
# ../../cap2input/stage1/220223b46a23db0e2b0577170936845d/
# int16
# (336, 20)
# ../../cap2input/stage1/149ff4b37a684a73869d2d88e3fd4d0e/
# int16
# (126, 20)
# ../../cap2input/stage1/380eb569a5750648434cc8ae8da4a0a9/
# int16
# (120, 20)
# ../../cap2input/stage1/9b259149a750af0c21640624e4be964a/
# int16
# (132, 20)
# ../../cap2input/stage1/122c5c959fd98036c9972eec2062dc59/
# int16
# (211, 20)
# ../../cap2input/stage1/fd7c0fb3c0e764357aa58e5f047be614/
# int16
# (121, 20)
# ../../cap2input/stage1/a9c1d12dabcd5f5b13d2aad47e443684/
# uint16
# (176, 20)
# ../../cap2input/stage1/b4d5b618fdf3a5a1bcfb325a3715e99e/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/661ffa992ed2c23c37f1e7b82dc834d7/
# int16
# (150, 20)
# ../../cap2input/stage1/42e374c728e50cf2aaa78db97f24a82c/
# int16
# (131, 20)
# ../../cap2input/stage1/af1d0c2fcde369dd1b715460c2f704a2/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/6d75fe2462284150249a04d78781189e/
# int16
# (124, 20)
# ../../cap2input/stage1/dd281294b34eb6deb76ef9f38169d50e/
# int16
# (142, 20)
# ../../cap2input/stage1/afb37b10bd304fa2c7b70cfaf1f489ed/
# uint16
# (181, 20)
# ../../cap2input/stage1/9b7524785a9bf40f0651deeb3b05b75f/
# uint16
# (140, 20)
# ../../cap2input/stage1/35105d801880bd889bac5ee3771ed38b/
# int16
# (241, 20)
# ../../cap2input/stage1/16a4184e565f589622a70e82957ab54e/
# int16
# (185, 20)
# ../../cap2input/stage1/61017c23bbae6e17062ff582d1a237b3/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/8815efa67adb15b2f8cfd49ec992f48e/
# uint16
# (503, 20)
# ../../cap2input/stage1/96544665531e7f59bc2730e3c5f42e65/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/642c43727eee4bda71c0c30bf5cf1a2b/
# int16
# (106, 20)
# ../../cap2input/stage1/5bf71718aa1bdcada76f0683f8d6b41b/
# int16
# (116, 20)
# ../../cap2input/stage1/46199ffd681fd429aca3823c76f1034d/
# uint16
# (178, 20)
# ../../cap2input/stage1/3f6431400c2a07a46386dba3929da45d/
# uint16
# (162, 20)
# ../../cap2input/stage1/bfdf6f821031435d9a397afe001ad774/
# int16
# (158, 20)
# ../../cap2input/stage1/263a1c3bfa43556623e75ed901e3fd8f/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/eee8e1b2533abcb73e4b03969a3a5904/
# int16
# (143, 20)
# ../../cap2input/stage1/263fa87394ee296e31234364e75d05e2/
# int16
# (127, 20)
# ../../cap2input/stage1/c278a6dc82c323254ff53c58db759908/
# uint16
# (184, 20)
# ../../cap2input/stage1/4062f1ad138218af5a3dfa3186d2afe1/
# int16
# (264, 20)
# ../../cap2input/stage1/834dd009c49e7faaf8e4caba668a2d8f/
# uint16
# (203, 20)
# ../../cap2input/stage1/124c4188604434bcdec8358c8ddf9a8b/
# int16
# (166, 20)
# ../../cap2input/stage1/d1a20ef45bb03f93a407b492066f6d88/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/820dd342da11af3a062d1647b3736fdd/
# uint16
# (432, 20)
# ../../cap2input/stage1/b2d6eb577e716ade61ca89b6bb3dcabb/
# int16
# (121, 20)
# ../../cap2input/stage1/d7aa27d839b1ecb03dbf011af4bcb092/
# int16
# (157, 20)
# ../../cap2input/stage1/61917cf6407e793bc0edb60850009e85/
# uint16
# (304, 20)
# ../../cap2input/stage1/7917af5df3fe5577f912c5168c6307e3/
# uint16
# (366, 20)
# ../../cap2input/stage1/07bca4290a2530091ce1d5f200d9d526/
# uint16
# (132, 20)
# ../../cap2input/stage1/43fefd3f810ef71e0073d2415e7a6713/
# uint16
# (187, 20)
# ../../cap2input/stage1/c2bdfb6ab5192656b397459648221918/
# int16
# (141, 20)
# ../../cap2input/stage1/d2285c33945ab3421d753b4fc59ac3ce/
# int16
# (127, 20)
# ../../cap2input/stage1/763288341ee363a264fe45a28ea28c21/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/5ade88428e6463fa212d4c287228e8ed/
# uint16
# (230, 20)
# ../../cap2input/stage1/e33c25d0dbca5e54385f2100ce523467/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/01e349d34c06410e1da273add27be25c/
# uint16
# (159, 20)
# ../../cap2input/stage1/186a0877503b047a77eb9b38083be9c1/
# int16
# (297, 20)
# ../../cap2input/stage1/fa45178d023325b255a3d4fc3e96cb7d/
# int16
# (122, 20)
# ../../cap2input/stage1/318bf8045b625b40825552420abfe1ef/
# int16
# (181, 20)
# ../../cap2input/stage1/5fe048f36bd2da6bdb63d8ff3c4022cd/
# uint16
# (114, 20)
# ../../cap2input/stage1/fb7ae70f05b6441ac4ea7187ce7c45f7/
# uint16
# (149, 20)
# ../../cap2input/stage1/6540e089936a6c9d1f11939e96e6ab18/
# int16
# (148, 20)
# ../../cap2input/stage1/bf56e271a2aa37625192954157e9f64d/
# int16
# (262, 20)
# ../../cap2input/stage1/67ccc2ecd7716e1cab05caaedea99f4b/
# int16
# (177, 20)
# ../../cap2input/stage1/c6b722b00948587dd89a548f9639f447/
# int16
# (238, 20)
# ../../cap2input/stage1/750ed950a05e5fae10b4d25ed9bcd021/
# int16
# (175, 20)
# ../../cap2input/stage1/204bdd4a15f023eea66190972b66fd0f/
# uint16
# (164, 20)
# ../../cap2input/stage1/5f19d1c7bd7ceb691639cab9c1c2cb19/
# int16
# (201, 20)
# ../../cap2input/stage1/483b89a4ffbbd85acc8b9af5a541dd4d/
# int16
# (131, 20)
# ../../cap2input/stage1/89f003dbfbdbd18a5cdeb9b128cb075b/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/750680cce371800ea26576b694b32dc8/
# uint16
# (202, 20)
# ../../cap2input/stage1/f725f46908f16062fd12c141eb47c6a7/
# uint16
# (108, 20)
# ../../cap2input/stage1/b158f44c31f4121c865c828ff79fc73d/
# uint16
# (141, 20)
# ../../cap2input/stage1/335b129aacabdf9269b0bb12f148d15c/
# uint16
# (167, 20)
# ../../cap2input/stage1/d00ee8f03fb00562b2db35e90536ffc1/
# uint16
# (459, 20)
# ../../cap2input/stage1/4131820511c86a5e6b1e7721ab687049/
# uint16
# (146, 20)
# ../../cap2input/stage1/6cf71f5017945c9dd8bc0f5126eeef5b/
# int16
# (169, 20)
# ../../cap2input/stage1/1c24a09fa32147d9083ff93f171e1102/
# int16
# (143, 20)
# ../../cap2input/stage1/243e69389ae5738d3f89386b0efddbcd/
# int16
# (131, 20)
# ../../cap2input/stage1/e3a9a6f8d21c6c459728066bcf18c615/
# uint16
# (162, 20)
# ../../cap2input/stage1/274a81c75d244187247789bd71de2b3a/
# uint16
# (184, 20)
# ../../cap2input/stage1/722429bc9cb25d6f4b7a820c14bf2ab1/
# int16
# (116, 20)
# ../../cap2input/stage1/09b1c678fc1009d84a038cd879be4198/
# int16
# (142, 20)
# ../../cap2input/stage1/678c5ec1360784e0fe797208069e0bbb/
# int16
# (133, 20)
# ../../cap2input/stage1/6c1136ce7fbc5c7b503aa08da6abedd2/
# uint16
# (141, 20)
# ../../cap2input/stage1/2a549c66f24af964de6f25165c55e331/
# uint16
# (193, 20)
# ../../cap2input/stage1/25c369973827571098bdebf2a15c6ef2/
# uint16
# (167, 20)
# ../../cap2input/stage1/f37d1d5c299d4838b294cf82902675b0/
# int16
# (114, 20)
# ../../cap2input/stage1/c3e8db4f544e2d4ecb01c59551eb8ef0/
# uint16
# (178, 20)
# ../../cap2input/stage1/6d43fdb6eb1bec3a5f4febfd442e8c93/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/844032970cb66839f748512acba0be8e/
# int16
# (190, 20)
# ../../cap2input/stage1/ab9c7bef62d1ad65b824414087b6f06b/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/7dbc5207b9ec1a1921cc2f03f9b37684/
# int16
# (123, 20)
# ../../cap2input/stage1/e8be143b9f5e352f71043b24f79f5a17/
# int16
# (153, 20)
# ../../cap2input/stage1/f74cbe4dda0f80dd66e15e64563689c6/
# uint16
# (161, 20)
# ../../cap2input/stage1/359951e3d2768249211361665b99b735/
# int16
# (154, 20)
# ../../cap2input/stage1/4cc309d81bf3685d7def772862375a2a/
# uint16
# (210, 20)
# ../../cap2input/stage1/366cfab448dbe55fd63b01adac0b1c56/
# int16
# (276, 20)
# ../../cap2input/stage1/cd6be62834c72756738935f904ec9c2c/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/7cf1a65bb0f89323668034244a59e725/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/fbae4d04285789dfa32124c86586dd09/
# uint16
# (180, 20)
# ../../cap2input/stage1/72ed4046708e5607eb0a5703905438ee/
# int16
# (155, 20)
# ../../cap2input/stage1/60b1526597b82c98ce96fbe5014c0f2b/
# int16
# (163, 20)
# 100
# ../../cap2input/stage1/bcb416e94f3505c120a54dbfc0d5a234/
# int16
# (117, 20)
# ../../cap2input/stage1/bbf7a3e138f9353414f2d51f0c363561/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/9f19c381184ba62416025849c464630e/
# int16
# (154, 20)
# ../../cap2input/stage1/ac3345a5a05655c6bcce7d0b226a0042/
# int16
# (156, 20)
# ../../cap2input/stage1/06a90409e4fcea3e634748b967993531/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/1be4cf2de84adac4de0e090c9a15461c/
# int16
# (141, 20)
# ../../cap2input/stage1/a01074fefbae0234398c365adf970118/
# uint16
# (169, 20)
# ../../cap2input/stage1/d92998a73d4654a442e6d6ba15bbb827/
# uint16
# (138, 20)
# ../../cap2input/stage1/8c7b03ed7f61c7faa5a26e126d769404/
# uint16
# (135, 20)
# ../../cap2input/stage1/ef3be197823bfa8c6976ca2621e253d5/
# uint16
# (152, 20)
# ../../cap2input/stage1/3f37745d6516c29c597b797c50fe7839/
# int16
# (162, 20)
# ../../cap2input/stage1/8aaa3a09b1f20e950609a62a1de511df/
# uint16
# (218, 20)
# ../../cap2input/stage1/6993396b31078993e13cf9c0a6fd470b/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/f6bf2c352e3c5b13ae48f077570f3d15/
# int16
# (165, 20)
# ../../cap2input/stage1/d6d5ed3055d084a6abf0f97af3fe2ff0/
# int16
# (124, 20)
# ../../cap2input/stage1/2bb5f7e8f10e1e39b7f81b5aa98676ea/
# int16
# (123, 20)
# ../../cap2input/stage1/b5de57869d863bdc1b84b0194e79a9d3/
# int16
# (185, 20)
# ../../cap2input/stage1/c1ba619e3b49e0cb7798bd10465c2b29/
# int16
# (534, 20)
# ../../cap2input/stage1/c645eb8b7b7225457e61cf511a8e46e5/
# uint16
# (169, 20)
# ../../cap2input/stage1/4b2f615f5498ee9d935b0229a2e6bb19/
# int16
# (434, 20)
# ../../cap2input/stage1/55b06d60e7c0329787f81d1b7cbf9aa0/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/eacb38abacf1214f3b456b6c9fa78697/
# uint16
# (187, 20)
# ../../cap2input/stage1/e6f4757b8f315f31559c5c256cb8dead/
# int16
# (184, 20)
# ../../cap2input/stage1/8f28d220d960b67f799479f319373c21/
# int16
# (101, 20)
# ../../cap2input/stage1/d13d9be7873c99a9fde9d24a95f1590d/
# uint16
# (165, 20)
# ../../cap2input/stage1/cc1b7e34d9eba737c9fb91316463e8f7/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/f0459473753b99105e9723f122022ad0/
# uint16
# (163, 20)
# ../../cap2input/stage1/c0f2e3b499d10d147892579d0ad71321/
# uint16
# (174, 20)
# ../../cap2input/stage1/d7713d80767cfdaad5e3db537849d8d0/
# int16
# (183, 20)
# ../../cap2input/stage1/bedec8e1ad130a08faeec8ed81780d56/
# int16
# (170, 20)
# ../../cap2input/stage1/91d0606b85ab7dbc7bab718c1312f2df/
# int16
# (152, 20)
# ../../cap2input/stage1/1cf8e778167d20bf769669b4be96592b/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/34cb3ac3d04e0d961e7578713bee6bb2/
# uint16
# (119, 20)
# ../../cap2input/stage1/6faabf4152bf0ebfd91f686bc37a1f16/
# int16
# (134, 20)
# ../../cap2input/stage1/6379e4435f78a5e5c150c32146ece4d4/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/781cf9cc66e59f4586d9338630b95c1a/
# int16
# (170, 20)
# ../../cap2input/stage1/74b1b748971c474a8023f6406c54b18a/
# int16
# (179, 20)
# ../../cap2input/stage1/8269e2eb69b3ba38c48dd5ae6039e250/
# uint16
# (157, 20)
# ../../cap2input/stage1/6a08bc7a3156caf9b07bbb1f9b2861d2/
# uint16
# (371, 20)
# ../../cap2input/stage1/9e98136d07b953c3362e0a132c8810b6/
# int16
# (166, 20)
# ../../cap2input/stage1/f77fd9fd7966b346ce8e7efcb96c7c53/
# int16
# (165, 20)
# ../../cap2input/stage1/2117642550461db380a019bbd10a95e5/
# uint16
# (153, 20)
# ../../cap2input/stage1/328138837e6db638913332acb79c703e/
# int16
# (218, 20)
# ../../cap2input/stage1/9b4f0020e407fd7f980f4241fb6ac7ce/
# int16
# (442, 20)
# ../../cap2input/stage1/f44dd045f6dcb1e477e6d3dc0f29d7e8/
# int16
# (266, 20)
# ../../cap2input/stage1/6a145c28d3b722643f547dfcbdf379ae/
# int16
# (244, 20)
# ../../cap2input/stage1/0679e5fd67b7441b8094494033f3881f/
# int16
# (133, 20)
# ../../cap2input/stage1/327c4e9f365aec05222e253d1a80a1d4/
# int16
# (127, 20)
# ../../cap2input/stage1/6d3b16f2e60c3a1a4246f340dba73676/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/8a97ff581c17a49a3ef97144efde8a19/
# int16
# (158, 20)
# ../../cap2input/stage1/ad914d487aae66bcc2a7760a959d8a7c/
# uint16
# (147, 20)
# ../../cap2input/stage1/fd4c2d4738bc25a5c331dbc101f3323a/
# uint16
# (156, 20)
# ../../cap2input/stage1/ee984e8fba88691aac4992fbb14f6e97/
# int16
# (154, 20)
# ../../cap2input/stage1/58e4646cbead2fc4a6a1f86bf806e76f/
# uint16
# (191, 20)
# ../../cap2input/stage1/f73624b8b22774acf9a3e2c748131eac/
# int16
# (130, 20)
# ../../cap2input/stage1/e2ea2f046495909ff89e18e05f710fee/
# int16
# (220, 20)
# ../../cap2input/stage1/a2a4bc7708f6831470d757cd6f32bffe/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/34c0760406297a3c8fd5077fb7cd95b0/
# int16
# (125, 20)
# ../../cap2input/stage1/baf842dd446ce9d7082efe16d22fb971/
# int16
# (145, 20)
# ../../cap2input/stage1/9050cf3aa8371bd7088c4bdf967141d4/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/14afefc82d992018c485949285d20c03/
# uint16
# (151, 20)
# ../../cap2input/stage1/5d240c6a6d3009e61cb09ce49f641b4c/
# uint16
# (171, 20)
# ../../cap2input/stage1/b42263b9b84f10464a94092e0cdc13b1/
# int16
# (283, 20)
# ../../cap2input/stage1/8264a875a465c029f28110c725fec283/
# int16
# (379, 20)
# ../../cap2input/stage1/665ca5ce18dd06722a4c4436a85246b2/
# uint16
# (150, 20)
# ../../cap2input/stage1/ca4e1486c548679a9c682b6fa1a779d9/
# int16
# (115, 20)
# ../../cap2input/stage1/dcf5fd36b9fff9183f63df286bf8eef9/
# uint16
# (143, 20)
# ../../cap2input/stage1/dc9854bcdcc71b690d9806438009001d/
# int16
# (172, 20)
# ../../cap2input/stage1/eba4bfb93928d424ff21b5be96b5c09b/
# int16
# (148, 20)
# ../../cap2input/stage1/597643aa6bb96b705eac52e03a307d6d/
# uint16
# (177, 20)
# ../../cap2input/stage1/521924ac2f00a62cc63f679de7e599cd/
# int16
# (172, 20)
# ../../cap2input/stage1/2eb92d17ca91b393765e8acf069763a6/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/14c534e0b7c3176d9106c6215d0aa8c6/
# uint16
# (194, 20)
# ../../cap2input/stage1/0fe244f21893c45fbb877f54d008518b/
# uint16
# (138, 20)
# ../../cap2input/stage1/e42815372aa308f5943847ad06f529de/
# uint16
# (195, 20)
# ../../cap2input/stage1/be57c648eb683a31e8499e278a89c5a0/
# uint16
# (162, 20)
# ../../cap2input/stage1/c004a9415539a0bc98c42c1a444cedb8/
# int16
# (122, 20)
# ../../cap2input/stage1/9d44fcc8ab801ac9244da4c016d0541e/
# int16
# (258, 20)
# ../../cap2input/stage1/4cd70a98baca46b116071b32788d3c2d/
# uint16
# (214, 20)
# ../../cap2input/stage1/3ee1fd6a0f3f108c3558e6699fb011f2/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/95edad4544e59e37188dd33db40cecb7/
# int16
# (282, 20)
# ../../cap2input/stage1/a19a122fe9a790576b57c6bd5cf9ff5c/
# int16
# (159, 20)
# ../../cap2input/stage1/5275c7ec0f1d80c829611c378708c05b/
# uint16
# (162, 20)
# ../../cap2input/stage1/52f6d741e674f62fbcf73e6ec4f6a472/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/33dd6666d9f0338929ecce58bb7c4cc3/
# uint16
# (158, 20)
# ../../cap2input/stage1/43fecc8947e4fbb47968dc8ef7d8f4ec/
# int16
# (151, 20)
# ../../cap2input/stage1/3187b6cf14ed2cbe611b01da5e161f21/
# int16
# (385, 20)
# ../../cap2input/stage1/0bd0e3056cbf23a1cb7f0f0b18446068/
# int16
# (280, 20)
# ../../cap2input/stage1/76f36ea4858c572b425eb915e1b27c8d/
# uint16
# (141, 20)
# ../../cap2input/stage1/f7a03adba817f2a2249b9dee0586f4be/
# int16
# (139, 20)
# ../../cap2input/stage1/718f43ecf121c79899caba1e528bd43e/
# uint16
# (119, 20)
# ../../cap2input/stage1/4b6b53281fe1fe797e181a5287df0f9a/
# int16
# (279, 20)
# ../../cap2input/stage1/00edff4f51a893d80dae2d42a7f45ad1/
# int16
# (135, 20)
# ../../cap2input/stage1/f0f72264cd822301852578cc71288d3c/
# int16
# (179, 20)
# ../../cap2input/stage1/8e60f166f1f1dc0d72f997fe1c9e72b4/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/5d801b07718dc9a1ad2bf701523a0f74/
# uint16
# (187, 20)
# ../../cap2input/stage1/99579bbe92d0bb4d5cd98982305870af/
# int16
# (244, 20)
# ../../cap2input/stage1/80a3052f4a1b90fd38fd0def7b79b65c/
# int16
# (235, 20)
# ../../cap2input/stage1/e314fd13809db0132443b924401d828b/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/4348beb99dacd2cbf14983a2c64a00c6/
# uint16
# (217, 20)
# 200
# ../../cap2input/stage1/ea01deecde93cd9503a049d71d46e6d5/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/8c4d81d9d24d9d66e9ced5f40d07960a/
# uint16
# (188, 20)
# ../../cap2input/stage1/799c0026d66479f7447ed0df5955f051/
# int16
# (253, 20)
# ../../cap2input/stage1/fbe0c3d6e4a50ca1c1bd3101515d0ab4/
# uint16
# (136, 20)
# ../../cap2input/stage1/2895ce2fe73dd62554326c3ab1c3b686/
# int16
# (148, 20)
# ../../cap2input/stage1/a647d0ce63b01c9ee82fe1911ba7b1e5/
# int16
# (183, 20)
# ../../cap2input/stage1/c25876fb40d6f8dafd1ecb243193dd3f/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/763ce10dfdd4662f15de3f5931d5534b/
# int16
# (150, 20)
# ../../cap2input/stage1/9cc74e673ec9807ee055973e1b185624/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/5e0c8cba8eab51076ac0014049d770c1/
# uint16
# (156, 20)
# ../../cap2input/stage1/7367ede966b44c6dce30b83345785671/
# int16
# (267, 20)
# ../../cap2input/stage1/e5cf847e616cc2fe94816ffa547d2614/
# int16
# (153, 20)
# ../../cap2input/stage1/83463d2951670b7e8c3efd7594a13e10/
# uint16
# (166, 20)
# ../../cap2input/stage1/f136a3df63637b499704a49fc0e3dfaf/
# uint16
# (192, 20)
# ../../cap2input/stage1/5b642ed9150bac6cbd58a46ed8349afc/
# int16
# (254, 20)
# ../../cap2input/stage1/43f2ef8f53e1aa03bfb6378d0c20a8ac/
# uint16
# (487, 20)
# ../../cap2input/stage1/8f0c4220a437192a30ae06d82bf78885/
# uint16
# (198, 20)
# ../../cap2input/stage1/cc24c86f88a9d17c04255a4d264030e6/
# uint16
# (129, 20)
# ../../cap2input/stage1/e60d99ea9648e1ce859eb0b386365e26/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/f8ecf6be8ae631c6dd694c9638a02b45/
# int16
# (132, 20)
# ../../cap2input/stage1/a2d9e657a673798f9ebdfec1b361f93a/
# int16
# (140, 20)
# ../../cap2input/stage1/abc4cfb4ac045b4f9a74e2dbb18f8193/
# int16
# (134, 20)
# ../../cap2input/stage1/0c9d8314f9c69840e25febabb1229fa4/
# int16
# (221, 20)
# ../../cap2input/stage1/fd0c2dfe0b0c58330675c3191cef0d5b/
# uint16
# (157, 20)
# ../../cap2input/stage1/d244870d213a21efa86e86c951d8c9a2/
# uint16
# (252, 20)
# ../../cap2input/stage1/eefc3f380cc72d6fa830972151df01ad/
# uint16
# (180, 20)
# ../../cap2input/stage1/91d29bc19205f8eb9a63de5b774a5575/
# int16
# (227, 20)
# ../../cap2input/stage1/8615d91dab90b906088e4097fc822820/
# uint16
# (318, 20)
# ../../cap2input/stage1/592c2481f17d6a2cecfe7bbb6a27722c/
# uint16
# (174, 20)
# ../../cap2input/stage1/9fc639cbbd749117de4980420ae52cf3/
# uint16
# (157, 20)
# ../../cap2input/stage1/b3c2d92976acd67a13493cdff1ec33ce/
# uint16
# (183, 20)
# ../../cap2input/stage1/436fd6ccfc92afc44c7d3ccfe26b6129/
# uint16
# (107, 20)
# ../../cap2input/stage1/b844a9510fc4021d9603cdf24cf0545b/
# int16
# (128, 20)
# ../../cap2input/stage1/4b28f147cb82baba3edcdbd34ca19085/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/aaeb75b838690ba6ba425f73b9773479/
# uint16
# (131, 20)
# ../../cap2input/stage1/166a2a476b7b84c975fb65162acc0798/
# int16
# (163, 20)
# ../../cap2input/stage1/7842c108866fccf9b1b56dca68fc355e/
# int16
# (164, 20)
# ../../cap2input/stage1/a162d204827e4e89a2e5ba81cc53247a/
# uint16
# (163, 20)
# ../../cap2input/stage1/8a1e5830a16db34b580202f8b6dbbd3d/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/6e3a7f8ef70e26252d25cc105a945f86/
# uint16
# (168, 20)
# ../../cap2input/stage1/c713ec80637677965806579fce0b7dca/
# uint16
# (304, 20)
# ../../cap2input/stage1/a4ae73433e63549558a3d0eed9128a69/
# int16
# (150, 20)
# ../../cap2input/stage1/cbb9bbd994c235b56fb77429291edf99/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/d032116d73789ff9c805f493357b4037/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/9d8bdc380b51812ba82a6040ef207c33/
# int16
# (166, 20)
# ../../cap2input/stage1/c3a9046fbe2b0f0a4e43a669c321e472/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/9f49140c0447a0c3108ba3591b11958f/
# int16
# (116, 20)
# ../../cap2input/stage1/70671fa94231eb377e8ac7cba4650dfb/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/0c0de3749d4fe175b7a5098b060982a1/
# int16
# (123, 20)
# ../../cap2input/stage1/665c1913d8e90e57af3b745349d19537/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/8c9925cf3627cd4742bbc8677f905afc/
# uint16
# (133, 20)
# ../../cap2input/stage1/efcb6def7a2080243052b6046186ab24/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/649fd56ef9809019b57261fcf9574d76/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/3a78dcf53effd732bc3880c029154272/
# int16
# (125, 20)
# ../../cap2input/stage1/a13d6c5f8f86d74e16c10cf9294bca31/
# uint16
# (141, 20)
# ../../cap2input/stage1/ae4e9d8aab8f8f5ae975bcca923f468d/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/c979fbec565e769de7e66944ab5365a4/
# uint16
# (232, 20)
# ../../cap2input/stage1/2143d78ca33eb69f667edd80ddbff6de/
# int16
# (255, 20)
# ../../cap2input/stage1/b79126e0038faca869185cfe49a4e163/
# int16
# (277, 20)
# ../../cap2input/stage1/caa6c81b74054858772bda6c2a0e8ee6/
# int16
# (267, 20)
# ../../cap2input/stage1/dbfbc12c7a943a2dc0e34bfd4a636bca/
# int16
# (225, 20)
# ../../cap2input/stage1/2e8bb42ed99b2bd1d9cd3ffaf5129e4c/
# int16
# (233, 20)
# ../../cap2input/stage1/608202eb3c368512e55e9e339a203790/
# uint16
# (189, 20)
# ../../cap2input/stage1/59af702c21840ec18073b6b56c95e7fe/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/a14e41eea93d7667a87d458d5cb28272/
# int16
# (253, 20)
# ../../cap2input/stage1/eed4db0cb0576c274de569e98a56a270/
# int16
# (151, 20)
# ../../cap2input/stage1/4a1391269629d20359325873d11413c9/
# int16
# (205, 20)
# ../../cap2input/stage1/e56b9f25a47a42f4ae4085005c46109c/
# int16
# (163, 20)
# ../../cap2input/stage1/cf83e9933c484dd9073ed8314794b9f7/
# int16
# (133, 20)
# ../../cap2input/stage1/4b5970e5edc0d8389cabc6bc5d84265f/
# uint16
# (183, 20)
# ../../cap2input/stage1/84ed26b5d79da321711ed869b3cad2ea/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/0030a160d58723ff36d73f41b170ec21/
# int16
# (265, 20)
# ../../cap2input/stage1/402a18fa05523f80abb1e6d97793cc19/
# int16
# (145, 20)
# ../../cap2input/stage1/bbf958c2331a553d5699a1369b7f2bbf/
# uint16
# (189, 20)
# ../../cap2input/stage1/799b283083f1b6547d558f063b318e78/
# int16
# (150, 20)
# ../../cap2input/stage1/ac4e4bd5633dd74c99762acdba21934f/
# int16
# (158, 20)
# ../../cap2input/stage1/be024b0b5cf93c597758e65f348475af/
# uint16
# (177, 20)
# ../../cap2input/stage1/2ed8eb4430bf40f5405495a5ec22a76d/
# int16
# (130, 20)
# ../../cap2input/stage1/ced4f41abff9290b0638b0a25cd5a26d/
# int16
# (206, 20)
# ../../cap2input/stage1/cf0a772e90a14d77d664ce9baedf0e5c/
# int16
# (214, 20)
# ../../cap2input/stage1/20c73e37fc89e007ae5b242480830860/
# int16
# (210, 20)
# ../../cap2input/stage1/04a8c47583142181728056310759dea1/
# int16
# (151, 20)
# ../../cap2input/stage1/f5ff7734997820b45dafa75dff60ece8/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/820245d8b211808bd18e78ff5be16fdb/
# int16
# (137, 20)
# ../../cap2input/stage1/19f3b4dea7af5d6e13acb472d6af23d8/
# int16
# (130, 20)
# ../../cap2input/stage1/1ff6e2a80eb74396e09460c61ae69fb0/
# int16
# (173, 20)
# ../../cap2input/stage1/321364cc2393dccb7ba8894ee9d2b269/
# int16
# (122, 20)
# ../../cap2input/stage1/013395589c01aa01f8df81d80fb0e2b8/
# uint16
# (217, 20)
# ../../cap2input/stage1/4baa552f3a11782f39e16b345d401fb8/
# uint16
# (231, 20)
# ../../cap2input/stage1/e2a7eaebd0830061e77690aa48f11936/
# uint16
# (167, 20)
# ../../cap2input/stage1/5bb9185543527cd034aa48fc0b623874/
# int16
# (126, 20)
# ../../cap2input/stage1/96cca9d8e5764daa4bcb6c0ba07735bc/
# int16
# This is unlabeled data!
# ../../cap2input/stage1/d39d18ec79c7303a61f778f470d439ae/
# uint16
# (180, 20)
# ../../cap2input/stage1/6d60c26d7d35ffd967127b380ff01c12/
# int16
# (176, 20)
# ../../cap2input/stage1/abc526fd74d0fdd73772bc6867bc38a4/
# int16
# (120, 20)
# ../../cap2input/stage1/82289d2db2b1e33d68ba6736b21b0e43/
# int16
# (133, 20)
# ../../cap2input/stage1/3464083b3e6e7c11d1fba925f0b914cd/
# int16
# (271, 20)
# ../../cap2input/stage1/fad57a1078ddbc685e517bd8f24aa8ac/
# uint16
# This is unlabeled data!
# ../../cap2input/stage1/506b07466777f6c6f4dd50a42896a2c4/
# int16
# (259, 20)
# ../../cap2input/stage1/d9a2bea7df4a888313374beb142cf9c0/
# int16
# (116, 20)
# 300
# ../../cap2input/stage1/435cd5883a2014f295a8081ea098674b/
# int16
# (306, 20)
