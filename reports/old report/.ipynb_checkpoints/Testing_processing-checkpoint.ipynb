# %% [markdown]
# # Machine Learning Part 1: Testing Data Processing
#
# This file is get the data ready for testing the CNN algorithm

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import skimage, os
from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from scipy import ndimage as ndi

# %matplotlib inline

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import dicom
import scipy.misc
import numpy as np

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../../cap2input"]).decode("utf8"))
# Out:
# sample_images
# stage1
# stage1_labels.csv
# stage1_sample_submission.csv
# stage1_solution.csv
# stage2
# stage2.7z
# stage2_sample_submission.csv.zip
# stage2_solution.csv

# %%
def read_ct_scan(folder_name):
        # Read the slices from the dicom file
        slices = [dicom.read_file(folder_name + filename) for filename in os.listdir(folder_name)]
        
        # Sort the dicom slices in their respective order
        slices.sort(key=lambda x: int(x.InstanceNumber))
        
        # Get the pixel values for all the slices
        image = np.stack([s.pixel_array for s in slices])
        intercept = int(slices[0].RescaleIntercept)
        image[image <= -1900] = -1000-intercept
        
        for slice_number in range(len(slices)):
        
            intercept = float(slices[slice_number].RescaleIntercept)
            slope = int(slices[slice_number].RescaleSlope)
            
            #print(intercept,slope)
        
            if slope != 1:
                image[slice_number] = slope * image[slice_number].astype(np.float64)
                
            image[slice_number] = image[slice_number].astype(np.int16)
            intercept = np.int16(intercept)

            image[slice_number] += intercept.astype(image[slice_number].dtype)
        print image.dtype
            
        return np.array(image, dtype=np.int16)
    
THRES = -400

def get_segmented_lungs(im, plot=False):
    '''
    This funtion segments the lungs from the given 2D slice.
    '''
    if plot == True:
        f, plots = plt.subplots(8, 1, figsize=(5, 40))
    '''
    Step 1: Convert into a binary image. 
    '''
    binary = im < THRES
    if plot == True:
        plots[0].axis('off')
        plots[0].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 2: Remove the blobs connected to the border of the image.
    '''
    cleared = clear_border(binary)
    if plot == True:
        plots[1].axis('off')
        plots[1].imshow(cleared, cmap=plt.cm.bone) 
    '''
    Step 3: Label the image.
    '''
    label_image = label(cleared)
    if plot == True:
        plots[2].axis('off')
        plots[2].imshow(label_image, cmap=plt.cm.bone) 
    '''
    Step 4: Keep the labels with 2 largest areas.
    '''
    areas = [r.area for r in regionprops(label_image)]
    areas.sort()
    if len(areas) > 2:
        for region in regionprops(label_image):
            if region.area < areas[-2]:
                for coordinates in region.coords:                
                       label_image[coordinates[0], coordinates[1]] = 0
    binary = label_image > 0
    if plot == True:
        plots[3].axis('off')
        plots[3].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 5: Erosion operation with a disk of radius 2. This operation is 
    seperate the lung nodules attached to the blood vessels.
    '''
    selem = disk(2)
    binary = binary_erosion(binary, selem)
    if plot == True:
        plots[4].axis('off')
        plots[4].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 6: Closure operation with a disk of radius 10. This operation is 
    to keep nodules attached to the lung wall.
    '''
    selem = disk(12)
    binary = binary_closing(binary, selem)
    if plot == True:
        plots[5].axis('off')
        plots[5].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 7: Fill in the small holes inside the binary mask of lungs.
    '''
    edges = roberts(binary)
    binary = ndi.binary_fill_holes(edges)
    if plot == True:
        plots[6].axis('off')
        plots[6].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 8: Superimpose the binary mask on the input image.
    '''
    get_high_vals = binary == 0
    im[get_high_vals] = -1000
    if plot == True:
        plots[7].axis('off')
        plots[7].imshow(im, cmap=plt.cm.bone) 
        
    return im

def segment_lung_from_ct_scan(ct_scan):
    return np.asarray([get_segmented_lungs(single_slice) for single_slice in ct_scan])

def plot_ct_scan(scan):
    f, plots = plt.subplots(int(scan.shape[0] / 20) + 1, 4, figsize=(25, 25))
    for i in range(0, scan.shape[0], 5):
        plots[int(i / 20), int((i % 20) / 5)].axis('off')
        plots[int(i / 20), int((i % 20) / 5)].imshow(scan[i], cmap=plt.cm.bone)
        
def plot_3d(image, threshold=-1300):
    
    # Position the scan upright, 
    # so the head of the patient would be at the top facing the camera
    p = image.transpose(2,1,0)
    p = p[:,:,::-1]
    
    verts, faces,_,_ = measure.marching_cubes(p, threshold)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh = Poly3DCollection(verts[faces], alpha=0.1)
    face_color = [0.5, 0.5, 1]
    mesh.set_facecolor(face_color)
    ax.add_collection3d(mesh)

    ax.set_xlim(0, p.shape[0])
    ax.set_ylim(0, p.shape[1])
    ax.set_zlim(0, p.shape[2])

    plt.show()

# %%
from skimage.morphology import opening
import cv2
import math

IMG_SIZE_PX = 50
SLICE_COUNT = 20

def chunks(l, n):
    # Credit: Ned Batchelder
    # Link: http://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunks
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]
        
def mean(a):
    return sum(a) / len(a)

def process_data(patient, labels_df, img_px_size=IMG_SIZE_PX, hm_slices=SLICE_COUNT, vis=False):
    path = data_dir + patient + '/'
    print path
    ct_scan = read_ct_scan(path)
    
    segmented_ct_scan = segment_lung_from_ct_scan(ct_scan)
    segmented_ct_scan[segmented_ct_scan < THRES] = -1000
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!   
    selem = ball(3) #was 3
    segmented_ct_scan = opening(segmented_ct_scan, selem)
    
    if vis == True:
        plot_3d(segmented_ct_scan, THRES)
        print(segmented_ct_scan[0].shape, len(segmented_ct_scan))
        
    slices_b = segmented_ct_scan
    new_slices = []
    slices_b = [cv2.resize(np.array(each_slice),(img_px_size,img_px_size)) for each_slice in slices_b]
    
    chunk_sizes = int(math.ceil(len(slices_b) / hm_slices))
    for slice_chunk in chunks(slices_b, chunk_sizes):
        slice_chunk = list(map(mean, zip(*slice_chunk)))
        new_slices.append(slice_chunk)
    
    while (len(new_slices) < hm_slices):
        new_slices.append(new_slices[-1])
        
    while (len(new_slices) > hm_slices):
        new_val = list(map(mean, zip(*[new_slices[hm_slices-1],new_slices[hm_slices],])))
        del new_slices[hm_slices]
        new_slices[hm_slices-1] = new_val
    
    label_b = labels_df.get_value(patient, 'cancer')

    if label_b == 1: label_b=np.array([0,1])
    elif label_b == 0: label_b=np.array([1,0])
        
    if vis == True:
        print(patient, label_b)
    print(len(slices_b), len(new_slices))
        
    return np.array(new_slices),label_b


data_dir = '../../cap2input/stage2/'
patients = os.listdir(data_dir)
#patient = 'ea7373271a2441b5864df2053c0f5c3e'
labels = pd.read_csv('../../cap2input/stage2_sample_submission.csv', index_col=0)

much_data = []
for num,patient in enumerate(patients):
    if num % 100 == 0:
        print(num)
    try:
        img_data,label_c = process_data(patient,labels,img_px_size=IMG_SIZE_PX, hm_slices=SLICE_COUNT)
        #print(img_data.shape,label)
        much_data.append([img_data,label_c,patient])
    except KeyError as e:
        print('This is unlabeled data!')

np.save('testdata-{}-{}-{}-b.npy'.format(IMG_SIZE_PX,IMG_SIZE_PX,SLICE_COUNT), much_data)

#process_data(patient, labels, vis = True)
# Out:
# 0
# ../../cap2input/stage2/7a632e7b8309e4b57a5964762a9e594a/
# int16
# /home/zexi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:50: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# (361, 20)
# ../../cap2input/stage2/d662c2884bf723e2b0b2401ccab08887/
# int16
# (313, 20)
# ../../cap2input/stage2/edde23221a8c4038f9a10daa3088ee94/
# int16
# (457, 20)
# ../../cap2input/stage2/91541739b4a106e5481a6156c5b3cfbb/
# int16
# (459, 20)
# ../../cap2input/stage2/d82af7a99fb96b2df37b4a0db270795f/
# int16
# (490, 20)
# ../../cap2input/stage2/2b76a32e5c12e4312cb029721a24b190/
# int16
# (295, 20)
# ../../cap2input/stage2/307a08ece9a33b772c903f5afbf9a799/
# int16
# (303, 20)
# ../../cap2input/stage2/5d669e1f9abdff1a282b924c828a9b0a/
# uint16
# (404, 20)
# ../../cap2input/stage2/ad690e1d0df849ee7983f69ab43e785c/
# int16
# (312, 20)
# ../../cap2input/stage2/c6c77fd425da262d6eeed53cff38cd91/
# uint16
# (418, 20)
# ../../cap2input/stage2/ff34be2a8759cadcae3ea0fc74d7ef7e/
# int16
# (328, 20)
# ../../cap2input/stage2/a59a4d0518786ac8ab13081238dd0757/
# uint16
# (443, 20)
# ../../cap2input/stage2/b4648347202a35b2926268cae562deb4/
# uint16
# (559, 20)
# ../../cap2input/stage2/bb324f0405a287f8cdc8bd4819bb44e4/
# int16
# (346, 20)
# ../../cap2input/stage2/ea001a72a1f5fa5f763f626223d650cf/
# int16
# (307, 20)
# ../../cap2input/stage2/65c63981709f8f86555dce488900dcd3/
# int16
# (123, 20)
# ../../cap2input/stage2/0e7eef8d0ccfdd8a67be5363043a8d5f/
# int16
# (130, 20)
# ../../cap2input/stage2/1eac4619a61c1bd6ad95880574cdb896/
# uint16
# (427, 20)
# ../../cap2input/stage2/860121cd3fe2f252911413653ab481e8/
# int16
# (133, 20)
# ../../cap2input/stage2/356f21ce2359091e3adbe4dd24247420/
# int16
# (323, 20)
# ../../cap2input/stage2/e492638dd22d58393cd680b9af7ad53a/
# int16
# (364, 20)
# ../../cap2input/stage2/419af46335739bb811e8bc97c3863836/
# int16
# (397, 20)
# ../../cap2input/stage2/d064eae583d8479a46c5858e6b1576ec/
# int16
# (325, 20)
# ../../cap2input/stage2/9882d82a9d9aaebc3610ef2d7936d54e/
# int16
# (363, 20)
# ../../cap2input/stage2/b4c66cb01e2407607fd5be9d897d38d3/
# int16
# (399, 20)
# ../../cap2input/stage2/dae65115273e56cd2b9c7a5a431f9aec/
# int16
# (478, 20)
# ../../cap2input/stage2/ccaa59eb37a705c4dc57d6f48199dc6b/
# int16
# (541, 20)
# ../../cap2input/stage2/7cecad958b5dedc511a23ff4a0463f50/
# int16
# (282, 20)
# ../../cap2input/stage2/72f1465b74aef9c003bb28ee55c0101d/
# uint16
# (94, 20)
# ../../cap2input/stage2/e65babe52dbff77a3efa66066cc5d9bd/
# uint16
# (107, 20)
# ../../cap2input/stage2/375d9053901012538eec892df7095761/
# int16
# (321, 20)
# ../../cap2input/stage2/8a676633a1fc178be886b040427d5b36/
# uint16
# (524, 20)
# ../../cap2input/stage2/660405919c9e059e97be72ab0d6da86f/
# int16
# (300, 20)
# ../../cap2input/stage2/31ac446f60a24d2fa8f536e2f37ce8b1/
# uint16
# (430, 20)
# ../../cap2input/stage2/63c86a1b73e2192b9785ff04d384d1bc/
# int16
# (273, 20)
# ../../cap2input/stage2/21bc3a25619dc957deacfdcece6c2cfe/
# int16
# (355, 20)
# ../../cap2input/stage2/5f5407caf46f8c699991db2d3e45c433/
# int16
# (333, 20)
# ../../cap2input/stage2/cf7afab6741f4175c6aae2536749b89f/
# int16
# (329, 20)
# ../../cap2input/stage2/6202db4b61c151e3e1d86cf5d3a75877/
# uint16
# (408, 20)
# ../../cap2input/stage2/825ea4ecda33bb0a3aa86188d8deec8b/
# int16
# (364, 20)
# ../../cap2input/stage2/3114085d28af476d88ae86ac98102eb6/
# int16
# (458, 20)
# ../../cap2input/stage2/0e05c8ea097f32da5e0420b7988c8c01/
# int16
# (421, 20)
# ../../cap2input/stage2/7b43f1a33e4ad43f4ebe63db679b5449/
# int16
# (376, 20)
# ../../cap2input/stage2/cf607785deb35514f475818a01267d0a/
# int16
# (322, 20)
# ../../cap2input/stage2/db8e5fe2c0c7e92db6cac98df51c3802/
# int16
# (237, 20)
# ../../cap2input/stage2/50befbc23d0dc9f7c22fd3490ec9d290/
# int16
# (318, 20)
# ../../cap2input/stage2/74645837e1bf20cb3b58d33d19201d09/
# int16
# (364, 20)
# ../../cap2input/stage2/20a3f01b7dca2a100dd61bb4ed8145a3/
# int16
# (490, 20)
# ../../cap2input/stage2/945d134454f76dcc3225536fada26d60/
# int16
# (358, 20)
# ../../cap2input/stage2/63248fdafd2df302b57a479289d76105/
# int16
# (493, 20)
# ../../cap2input/stage2/a65e16100e362301faf3a14c4a12d8f6/
# int16
# (496, 20)
# ../../cap2input/stage2/53d9a24d85a380076126844ef31b88f4/
# int16
# (119, 20)
# ../../cap2input/stage2/6804d8d3bfec4bfe952878ffe6e09e73/
# uint16
# (469, 20)
# ../../cap2input/stage2/ce88ea7be9ce0b5e09aff074971ea2c6/
# int16
# (327, 20)
# ../../cap2input/stage2/fa5438ae2076bb00fee89929b02e89f5/
# int16
# (333, 20)
# ../../cap2input/stage2/71fb08e5d63e2ad9f7bf90db6cb6e4ce/
# int16
# (531, 20)
# ../../cap2input/stage2/ba61c237790ac6ebba86537ed080bec6/
# int16
# (309, 20)
# ../../cap2input/stage2/be07d18e089f88520b6d2d07c5f61998/
# uint16
# (526, 20)
# ../../cap2input/stage2/2cc9bceeb883bccbe68aaf265786be40/
# int16
# (307, 20)
# ../../cap2input/stage2/d7850f462f15f4e8a21bf883450a505c/
# int16
# (318, 20)
# ../../cap2input/stage2/7222c0c84f4355592dd5447e709157bd/
# int16
# (455, 20)
# ../../cap2input/stage2/da5c6c3187546b6f375227e6e05db385/
# int16
# (328, 20)
# ../../cap2input/stage2/b37b42625992ced93aa5b876292419e0/
# int16
# (530, 20)
# ../../cap2input/stage2/82ca3467a29a5fad86786cc98218c86a/
# int16
# (304, 20)
# ../../cap2input/stage2/c10ee335e6d785d5765a180c2d8e9eaa/
# int16
# (114, 20)
# ../../cap2input/stage2/ff9be3a6286f90d0b3ce7b049ac1cb9a/
# int16
# (344, 20)
# ../../cap2input/stage2/3baf46b1235654fccf4598cab21e4b9b/
# int16
# (333, 20)
# ../../cap2input/stage2/1a51f9a55a0cd6f8f221a384206ed00e/
# uint16
# (421, 20)
# ../../cap2input/stage2/3493bf9c7ee10c3dc33c8c383001dd4b/
# int16
# (373, 20)
# ../../cap2input/stage2/e55cc41f046bdcf6d38274d3891fee90/
# int16
# (364, 20)
# ../../cap2input/stage2/9a0bb97afb7d06bae48c8fb6688c41ea/
# int16
# (334, 20)
# ../../cap2input/stage2/92b29d369f39c5fd179bfa7ba367b675/
# int16
# (369, 20)
# ../../cap2input/stage2/4d89b973a357ad116b47b4f86a0a5af8/
# int16
# (321, 20)
# ../../cap2input/stage2/9d370238460a7eab91fc82b6d6b9be51/
# int16
# (327, 20)
# ../../cap2input/stage2/bbb1413bd9f388728e389074cad55253/
# int16
# (319, 20)
# ../../cap2input/stage2/b918c187af3f13428706b91c1bbe5251/
# uint16
# (173, 20)
# ../../cap2input/stage2/1cd64b69ba25e71b0dcef99e937907c0/
# int16
# (447, 20)
# ../../cap2input/stage2/7533462c0cc84608626f64247af52c4f/
# int16
# (321, 20)
# ../../cap2input/stage2/e20336e62431afedcc46892514e4c32d/
# int16
# (360, 20)
# ../../cap2input/stage2/678b4a8e39c885e4220f87f4fdacb18a/
# uint16
# (463, 20)
# ../../cap2input/stage2/bc3344f9c27ffb2983c2f7410eb49fba/
# int16
# (318, 20)
# ../../cap2input/stage2/d63bcca00bf9df3d3aca0973aba7f22a/
# int16
# (464, 20)
# ../../cap2input/stage2/368a29bb6c317958e06c1b6cfdc4a3a1/
# int16
# (294, 20)
# ../../cap2input/stage2/5b3b5b1ed611fb8d9578baaad9a3fd26/
# int16
# (286, 20)
# ../../cap2input/stage2/c690e7144dc2484b1ff15ca6f2f94537/
# int16
# (118, 20)
# ../../cap2input/stage2/172f016737a31607818a98360f25a0d6/
# int16
# (337, 20)
# ../../cap2input/stage2/c6981cd6a6c78440bf6f76fe32e5452a/
# uint16
# (413, 20)
# ../../cap2input/stage2/e7df00dcfea4ce7c8c40f66a526a4aa9/
# int16
# (392, 20)
# ../../cap2input/stage2/630942a485dfbf5fab1a902dcfbe450c/
# uint16
# (515, 20)
# ../../cap2input/stage2/bfa5a4e67d66547e7bba17b8af806b31/
# uint16
# (506, 20)
# ../../cap2input/stage2/6eb5aa3ad73133e503af19f4d95a19d5/
# int16
# (397, 20)
# ../../cap2input/stage2/d91b127929d2cfbb0eab376c30c24a91/
# int16
# (615, 20)
# ../../cap2input/stage2/96d7963166a20e337dae6f96c1893774/
# uint16
# (449, 20)
# ../../cap2input/stage2/d1a28c25b21ebca8bfcf0b5dff0481a1/
# uint16
# (485, 20)
# ../../cap2input/stage2/0d9cf9a58fed5993e533f983b5222b5c/
# uint16
# (421, 20)
# ../../cap2input/stage2/9707c7b8191f0f1ea63346a60a2a3d69/
# int16
# (331, 20)
# ../../cap2input/stage2/92774bd1b239328d8ce809223e3334b4/
# int16
# (345, 20)
# ../../cap2input/stage2/59c90b8b518f7cc17c781121c62641b4/
# uint16
# (507, 20)
# ../../cap2input/stage2/9f6c458b4276ddbc0ebaa374037bb099/
# int16
# (121, 20)
# ../../cap2input/stage2/0bc0b23e7710f910ef3ebc55fb5844ac/
# uint16
# (503, 20)
# 100
# ../../cap2input/stage2/d2236754bfeaa0315dac239dc077f441/
# int16
# (325, 20)
# ../../cap2input/stage2/354434f3ebd3ac5f94c226db8a8e58a1/
# int16
# (322, 20)
# ../../cap2input/stage2/d2810292b19fdcb287bf9aa8e97526d5/
# int16
# (346, 20)
# ../../cap2input/stage2/401c2a2e7ff122ec5c558089d8ae3586/
# int16
# (535, 20)
# ../../cap2input/stage2/92fed3184f1c712e551e9631988bea57/
# uint16
# (505, 20)
# ../../cap2input/stage2/4eb7ea2cb6e3ebf6a9ac680665c58970/
# int16
# (322, 20)
# ../../cap2input/stage2/9f2e0344d97a73499ac3c2f364177660/
# uint16
# (360, 20)
# ../../cap2input/stage2/7513342e12f6ff612403693c7fbf3cdc/
# uint16
# (100, 20)
# ../../cap2input/stage2/8b654e8dd9e0ceed5fd1dcc512b20aac/
# uint16
# (478, 20)
# ../../cap2input/stage2/509ccdf238d65f198375fb5ff3afaceb/
# int16
# (329, 20)
# ../../cap2input/stage2/1f80571a52f38a5d9c029149612cb553/
# int16
# (331, 20)
# ../../cap2input/stage2/a76e3f34b94cbdc8e1311d7231dba495/
# int16
# (343, 20)
# ../../cap2input/stage2/7d7d8091cfdee500502c9629220adc36/
# int16
# (294, 20)
# ../../cap2input/stage2/315ca8a98de38b056e9432cff8896d4e/
# int16
# (319, 20)
# ../../cap2input/stage2/d8306381975ac352e94c3c8e4b267805/
# int16
# (352, 20)
# ../../cap2input/stage2/4c16f378fb0331125ab6479267c18d81/
# int16
# (474, 20)
# ../../cap2input/stage2/d07e1c7ef5deebffe8af36e4039d0346/
# int16
# (358, 20)
# ../../cap2input/stage2/20be9b64e208cdd20d01899b4214ea68/
# uint16
# (434, 20)
# ../../cap2input/stage2/41b47383fb53e8ed474be0aa123eb73c/
# int16
# (321, 20)
# ../../cap2input/stage2/691f4dee0daa3a348c42d650f37e6a8e/
# int16
# (531, 20)
# ../../cap2input/stage2/ff339fd5b4bfc7e916591ecc88286584/
# uint16
# (511, 20)
# ../../cap2input/stage2/beb7e1aeed9055886b19b905261fc63c/
# int16
# (497, 20)
# ../../cap2input/stage2/6202d9530fc2c8619575af4ab1509ba6/
# int16
# (378, 20)
# ../../cap2input/stage2/769777492f8397ae6f3494288bd76635/
# int16
# (327, 20)
# ../../cap2input/stage2/80cf1bcee0d610ca333975046f1908f1/
# uint16
# (445, 20)
# ../../cap2input/stage2/d3487496a29858e898b80cc33319e440/
# int16
# (375, 20)
# ../../cap2input/stage2/310567602ee5b46a96cc8fad78defcd9/
# int16
# (112, 20)
# ../../cap2input/stage2/d7f86fbd451c55c5787c531ee97ba519/
# int16
# (324, 20)
# ../../cap2input/stage2/a156797790636acf4bfecafcd80d0af6/
# int16
# (333, 20)
# ../../cap2input/stage2/28b6f19fbb5c6508faace72f8c82a5f4/
# uint16
# (116, 20)
# ../../cap2input/stage2/37f046c4e2bbc062bb103b302b22beef/
# uint16
# (575, 20)
# ../../cap2input/stage2/2b755f4208d310aa91682f4557744771/
# uint16
# (475, 20)
# ../../cap2input/stage2/a1a1199e75d341bf791aa2d188e38426/
# uint16
# (477, 20)
# ../../cap2input/stage2/c52e392d91dbb369308c95214a26bbed/
# int16
# (250, 20)
# ../../cap2input/stage2/f2ab5b6325311e494ffe3f588fdedd4d/
# int16
# (460, 20)
# ../../cap2input/stage2/db63bcc5f04a99f5290711f8f618732d/
# int16
# (481, 20)
# ../../cap2input/stage2/4434c5c933b67ce29d62b2556ebd4b0d/
# uint16
# (474, 20)
# ../../cap2input/stage2/d0e799ddcb62425be06a7d568f15f27d/
# int16
# (481, 20)
# ../../cap2input/stage2/a7cd3504885992799118f0c0068a1ed4/
# int16
# (459, 20)
# ../../cap2input/stage2/8bb78b08c671f1c52d03d29f56997640/
# int16
# (471, 20)
# ../../cap2input/stage2/e3c32315bc41d2deaa21165864aeac7f/
# int16
# (331, 20)
# ../../cap2input/stage2/0997c605045ff2b3a410fcf03de497a6/
# int16
# (342, 20)
# ../../cap2input/stage2/3ccc6a9ca8d06cf18c0970ff60d4551a/
# int16
# (434, 20)
# ../../cap2input/stage2/142eeb50ea40e58a2529f2099040d3ea/
# int16
# (509, 20)
# ../../cap2input/stage2/05e708a2a57caa99a3caf0327cbc5382/
# int16
# (283, 20)
# ../../cap2input/stage2/5921878df8f86a9c631c45e60b1f7e39/
# int16
# (350, 20)
# ../../cap2input/stage2/65bbe25cb1687acc469829d830ce1509/
# int16
# (322, 20)
# ../../cap2input/stage2/df34fa35d3dae830d78ccc47fcada139/
# uint16
# (435, 20)
# ../../cap2input/stage2/5337ae7044c143d8cfbf060b4ed8301e/
# int16
# (351, 20)
# ../../cap2input/stage2/a260e23b4150bbea92f27591a3639419/
# uint16
# (477, 20)
# ../../cap2input/stage2/58fb0172fb3a4d749e7f967a2c65fb0c/
# int16
# (304, 20)
# ../../cap2input/stage2/76a4ae03f3f94df78567023b069c89ef/
# uint16
# (95, 20)
# ../../cap2input/stage2/5bcb6eda63001cfce086f1fe5de51f41/
# int16
# (321, 20)
# ../../cap2input/stage2/019cb268efb93de5446984242bac0380/
# uint16
# (465, 20)
# ../../cap2input/stage2/f25d655012762acc9898a41b29e008e3/
# int16
# (478, 20)
# ../../cap2input/stage2/c8690d3efb5cbfcb9f2871fe19a3b32f/
# uint16
# (341, 20)
# ../../cap2input/stage2/e8ec84f7b36c66d9258b06951c75d06f/
# int16
# (521, 20)
# ../../cap2input/stage2/5939becdf1bce96a1f582a3f30670a04/
# int16
# (272, 20)
# ../../cap2input/stage2/0253545cc6415a055faad7192f31a1ca/
# int16
# (539, 20)
# ../../cap2input/stage2/f5f6f6aa533a0767f7687a7d96ac5a0a/
# int16
# (361, 20)
# ../../cap2input/stage2/22de96dca2a824e804b6769b48be0b3c/
# int16
# (355, 20)
# ../../cap2input/stage2/4cb50cb09776aa28783dd3755daece75/
# int16
# (331, 20)
# ../../cap2input/stage2/335a834f795a4549ab818dd19090f147/
# int16
# (481, 20)
# ../../cap2input/stage2/5217b9314309ade8865150aca3912524/
# uint16
# (461, 20)
# ../../cap2input/stage2/2da189e3c5b1c6758f6ead8e198fb116/
# int16
# (546, 20)
# ../../cap2input/stage2/97cdfe259a3bd124def9b444746b72bd/
# int16
# (306, 20)
# ../../cap2input/stage2/43d3d1c088b0f6e7056391fd914a6f58/
# int16
# (346, 20)
# ../../cap2input/stage2/15e96a2ba69d4f8af4d44e75a1cfc91f/
# int16
# (337, 20)
# ../../cap2input/stage2/3e4568aa1b37bd06f3917bc505ab6c2a/
# int16
# (334, 20)
# ../../cap2input/stage2/0ba7cbccf5668379da4a78f1b12e3211/
# uint16
# (160, 20)
# ../../cap2input/stage2/11bba83081cc441e2c8bbaed2f84f8d6/
# int16
# (253, 20)
# ../../cap2input/stage2/4b1e5ed061a8a2dc64d212584e1d6a4c/
# int16
# (485, 20)
# ../../cap2input/stage2/1be7f244f01ddac76d864e9d1fe6d6ee/
# int16
# (250, 20)
# ../../cap2input/stage2/19df071f31180ed0e0620a5f914abf7a/
# int16
# (379, 20)
# ../../cap2input/stage2/22d0e88e673e56a05c0edf153e5ccaee/
# int16
# (310, 20)
# ../../cap2input/stage2/1ad3aba8f62816a864078e030a6fd6dc/
# int16
# (123, 20)
# ../../cap2input/stage2/bfa308aee025f633de3c9c727b40bec1/
# int16
# (315, 20)
# ../../cap2input/stage2/3cf14368b567863b5e3214080cc101f4/
# int16
# (351, 20)
# ../../cap2input/stage2/e70408f9fcebca9c347ffc3e2dcbcf51/
# int16
# (291, 20)
# ../../cap2input/stage2/20a8ead8311e8cc33023b6a1e1f94909/
# int16
# (367, 20)
# ../../cap2input/stage2/03990e71d5a98502e4e7f63f8203d760/
# int16
# (358, 20)
# ../../cap2input/stage2/370f849df7e2b4570548158dfc63a90c/
# uint16
# (320, 20)
# ../../cap2input/stage2/d9131e64fc15ee38e3e28ed97b2f1dd6/
# int16
# (106, 20)
# ../../cap2input/stage2/a77b5a7654310f555e04a046711b81b6/
# int16
# (535, 20)
# ../../cap2input/stage2/c0f0e7479900bd05e349af2df690be73/
# int16
# (110, 20)
# ../../cap2input/stage2/350f68009d00a66a792de02eec87bd59/
# int16
# (593, 20)
# ../../cap2input/stage2/2d46ed30e23bdf071e5d80afeeee817d/
# int16
# (558, 20)
# ../../cap2input/stage2/dffa73c8f116400a9db317cedb1c355a/
# int16
# (448, 20)
# ../../cap2input/stage2/4751aa266a4567c77f2b4add96e42831/
# int16
# (361, 20)
# ../../cap2input/stage2/d2cdfbcadca86bcb7365bc86d9c29132/
# int16
# (536, 20)
# ../../cap2input/stage2/4a35aecab076185bb8c835ac412aef34/
# int16
# (333, 20)
# ../../cap2input/stage2/347539ba092da9aed8a3d09fb619a2d0/
# int16
# (520, 20)
# ../../cap2input/stage2/8fdba45607fbbb8ad5f59e469930ef5a/
# int16
# (325, 20)
# ../../cap2input/stage2/5d1dd71ccc0e5c54726daa38e0ec353c/
# int16
# (307, 20)
# ../../cap2input/stage2/6715bd7a3d2a9f51d267ff9d68513d96/
# int16
# (360, 20)
# ../../cap2input/stage2/f619be5384b06c6bec33c009cb0f055b/
# int16
# (465, 20)
# ../../cap2input/stage2/d9152daa459930defd9106d3fdb8e57c/
# int16
# (115, 20)
# ../../cap2input/stage2/d5505d4768c58657b193fe397006640a/
# int16
# (339, 20)
# ../../cap2input/stage2/3927bf095799b557c7e05c3c569b70c6/
# uint16
# (526, 20)
# ../../cap2input/stage2/e4c4740fbd129f96d26195bcf37214e4/
# int16
# (348, 20)
# 200
# ../../cap2input/stage2/7ee8b25a894f9c47f7c691cd5052f41d/
# int16
# (369, 20)
# ../../cap2input/stage2/3d8f006eeab0a4ea109ffe3901c7f695/
# int16
# (364, 20)
# ../../cap2input/stage2/ebe0b99f271c7c443d13dcb5cffdd2d2/
# int16
# (301, 20)
# ../../cap2input/stage2/16925ac5e9090bc173cee5d26517348e/
# int16
# (337, 20)
# ../../cap2input/stage2/ac2f2c8dd608b02f6ca61a0ec676a8bd/
# int16
# (376, 20)
# ../../cap2input/stage2/edad5e439ba696b89872f6b9af10cba0/
# int16
# (116, 20)
# ../../cap2input/stage2/9f1a8de97e37ba3b1b96e380062bd7b7/
# uint16
# (416, 20)
# ../../cap2input/stage2/5b64bb88d6f09b8c3c39966ab3464146/
# int16
# (519, 20)
# ../../cap2input/stage2/0504cf4053de140cf882df042ce79372/
# int16
# (474, 20)
# ../../cap2input/stage2/dc04811c9ca21c9373c76efd83436797/
# uint16
# (450, 20)
# ../../cap2input/stage2/59abaecfcab256bf142f88410575ebce/
# uint16
# (383, 20)
# ../../cap2input/stage2/b562506ce57553fd712f727b64202b61/
# int16
# (557, 20)
# ../../cap2input/stage2/5a06ebc438b934a360a5e469a6874505/
# int16
# (499, 20)
# ../../cap2input/stage2/582362101603718388d47d6da19aa51f/
# int16
# (397, 20)
# ../../cap2input/stage2/f81025619a4993f4e406f3ccd07e9c0b/
# int16
# (397, 20)
# ../../cap2input/stage2/1093f95635baf659ad5b3a893b14a0d9/
# int16
# (325, 20)
# ../../cap2input/stage2/148f7a4c3e46df7cd945c3ec96785ce8/
# int16
# (355, 20)
# ../../cap2input/stage2/73d79de3719e94cd1cefe1930a6575bf/
# int16
# (327, 20)
# ../../cap2input/stage2/a448a2c6764cb8915bd249a1a31a8477/
# int16
# (366, 20)
# ../../cap2input/stage2/00f6c1bd02eb49e3d8dbfc7d957a709e/
# int16
# (481, 20)
# ../../cap2input/stage2/e62c65f23653e8439a5176fe778cf8b1/
# int16
# (488, 20)
# ../../cap2input/stage2/01cb8771b8da81fc4a7cc48595832523/
# int16
# (525, 20)
# ../../cap2input/stage2/362762bb95ee02942433d6616dde42d4/
# int16
# (451, 20)
# ../../cap2input/stage2/696b170a3f0be65859b3186a6bc4c5cf/
# int16
# (321, 20)
# ../../cap2input/stage2/8d0361d5707806a174960eab9fa7f9a7/
# int16
# (322, 20)
# ../../cap2input/stage2/4870509d75603c7bd809595252a984d8/
# uint16
# (94, 20)
# ../../cap2input/stage2/4d7c36fb4b7009d4a90fc5b6ba4609c7/
# int16
# (115, 20)
# ../../cap2input/stage2/d039dd43c2b6fdb9c33d9a886017ada7/
# int16
# (479, 20)
# ../../cap2input/stage2/4914d4c1f572df3ea2980744360222d5/
# int16
# (122, 20)
# ../../cap2input/stage2/a7f444ec9c79c5bbb0ed6b7870b82fd1/
# int16
# (345, 20)
# ../../cap2input/stage2/f68e914a9970ec8ecc17b479f9c30e69/
# int16
# (458, 20)
# ../../cap2input/stage2/e6e9bc69bcdec893b0480402fcb0f1fe/
# int16
# (526, 20)
# ../../cap2input/stage2/e9a6d8a176b8a3dba1014cda189afd36/
# int16
# (448, 20)
# ../../cap2input/stage2/700b79db14b067a50de12eb2b47dc4a8/
# int16
# (467, 20)
# ../../cap2input/stage2/e76d4624942e8e8487e24e743599a67f/
# int16
# (333, 20)
# ../../cap2input/stage2/1510c7f1937b2a831ab3ffcb37eccf46/
# uint16
# (476, 20)
# ../../cap2input/stage2/4a180383b08dffe4f83a10d3e5df82e8/
# int16
# (444, 20)
# ../../cap2input/stage2/19e8b6ef9eba05cff426b15fff44b05a/
# int16
# (343, 20)
# ../../cap2input/stage2/1ff375d3f224a510dad6846df1cf19ab/
# uint16
# (559, 20)
# ../../cap2input/stage2/f560c34063bb88f85c41f1f9c1c165ac/
# int16
# (315, 20)
# ../../cap2input/stage2/e5a3991594ba6d7adcefbccc4dae0a85/
# int16
# (319, 20)
# ../../cap2input/stage2/dc8599e530bc81a46b2d400022490db9/
# int16
# (467, 20)
# ../../cap2input/stage2/11cfcfffa22dafe09fe05c351b3b7cd9/
# int16
# (333, 20)
# ../../cap2input/stage2/3b25cbd09937e9d0ff0e78177bb404a4/
# int16
# (319, 20)
# ../../cap2input/stage2/ed43e376ff1b9dbf971e6a1d6d9f863b/
# int16
# (448, 20)
# ../../cap2input/stage2/2929c9d58614c92b0e658e2dd5503225/
# uint16
# (434, 20)
# ../../cap2input/stage2/07ba80a4520fd85c686715bc0f7d7170/
# int16
# (388, 20)
# ../../cap2input/stage2/e6caff0cb14de3c50ee033fbd37930ac/
# int16
# (274, 20)
# ../../cap2input/stage2/2a2c070d42f8b7a64b7a0004812e01f8/
# uint16
# (451, 20)
# ../../cap2input/stage2/82689b6006173d5c9b37bb4b5731d77d/
# int16
# (378, 20)
# ../../cap2input/stage2/3baf8d721eca3d986c78de9c0cb800e3/
# uint16
# (509, 20)
# ../../cap2input/stage2/f39de0defd6bdc40f047a24c46b72330/
# int16
# (354, 20)
# ../../cap2input/stage2/27d974ad172ea4ed8276b0827e78ff34/
# uint16
# (533, 20)
# ../../cap2input/stage2/4454a74c78808fa9159513233f7c8baf/
# int16
# (361, 20)
# ../../cap2input/stage2/fb51f93cc69b6be7375f518092330197/
# uint16
# (440, 20)
# ../../cap2input/stage2/06a54f06a8eba76e85bb38e167fbc353/
# uint16
# (106, 20)
# ../../cap2input/stage2/989abd1a73e0b3f571d5a768720c8b59/
# int16
# (307, 20)
# ../../cap2input/stage2/4d45cf54de669600c0877c87de479b3d/
# int16
# (397, 20)
# ../../cap2input/stage2/1c0cdb7fc85cf4aee5cc44d1383edfbc/
# int16
# (310, 20)
# ../../cap2input/stage2/c7f551d09dc957ed69cbae202a493125/
# int16
# (331, 20)
# ../../cap2input/stage2/be5a81dfada5223d7885560a5a2304d6/
# uint16
# (555, 20)
# ../../cap2input/stage2/c593f9eda7fe8a586ecb41dd44ba0211/
# int16
# (366, 20)
# ../../cap2input/stage2/d46da2772bc43d5a52ccb6a7a75a370d/
# int16
# (360, 20)
# ../../cap2input/stage2/446ba66a6eee8ab987ccfbfdbcefadc4/
# int16
# (421, 20)
# ../../cap2input/stage2/7e7a302d89e7f88ae6d6da9ce0914d3e/
# int16
# (451, 20)
# ../../cap2input/stage2/d8074dffb2bb488356da89906fa4923e/
# int16
# (136, 20)
# ../../cap2input/stage2/a8c76017449033cfff49bf517b22b2fa/
# int16
# (121, 20)
# ../../cap2input/stage2/65d6bc5aaa876d81dead5d02d5638f98/
# int16
# (388, 20)
# ../../cap2input/stage2/b83d2c7d4d3fdeae1abe3a2baf19d23f/
# uint16
# (476, 20)
# ../../cap2input/stage2/713ab918fab889d881ce463a9066ffd4/
# int16
# (358, 20)
# ../../cap2input/stage2/738d498f03a6afa85f5b5d0cbc74e0a9/
# int16
# (373, 20)
# ../../cap2input/stage2/92b36c56e89856c06ccffdf61db49ba7/
# uint16
# (490, 20)
# ../../cap2input/stage2/4b997575c629b5d7c8fe2396b6d21eb7/
# int16
# (558, 20)
# ../../cap2input/stage2/eafa7b42b116a40a15f7804a3c51f35a/
# int16
# (357, 20)
# ../../cap2input/stage2/4dcc9cb21b2f06a72e83bb686d3e6d3f/
# int16
# (334, 20)
# ../../cap2input/stage2/60cdc2a04b344c7d1321c8e8c50897f4/
# int16
# (547, 20)
# ../../cap2input/stage2/9dce6c52598d38ed98b4010931db1837/
# int16
# (461, 20)
# ../../cap2input/stage2/46d86affd714f1c4d8e0d955ab4faf55/
# int16
# (325, 20)
# ../../cap2input/stage2/19e7e49fd4e9ad825d4f95b898bb6f7b/
# int16
# (465, 20)
# ../../cap2input/stage2/12606f5539b09c7f1a857b8c11702b2a/
# int16
# (130, 20)
# ../../cap2input/stage2/1cf841414a1eda13138f2493ecaf439c/
# int16
# (328, 20)
# ../../cap2input/stage2/2a988d75eee375a3cfe5c21b824a2c35/
# int16
# (489, 20)
# ../../cap2input/stage2/2503439e08a1e9232b80a625eeb26614/
# uint16
# (371, 20)
# ../../cap2input/stage2/539b7e3b33c85755c52a125a3f600c4e/
# int16
# (304, 20)
# ../../cap2input/stage2/d7fc3c406dae05d72a3d932944cd4a39/
# uint16
# (323, 20)
# ../../cap2input/stage2/e450e58e3651a7149c0ac40016ba8ac8/
# int16
# (373, 20)
# ../../cap2input/stage2/f357f3fd146b25833f597721cbc2d9d3/
# int16
# (328, 20)
# ../../cap2input/stage2/1cd9c6588c6d8422056d8ef03c628e84/
# int16
# (345, 20)
# ../../cap2input/stage2/f42f859925e385cfe8e44bc2a879f029/
# int16
# (125, 20)
# ../../cap2input/stage2/6bbec7c3b0f27605dc2eba370c68f890/
# int16
# (294, 20)
# ../../cap2input/stage2/0f704d66a922144905e4318d7cf45aa0/
# int16
# (461, 20)
# ../../cap2input/stage2/004828796b994741c4466f59a8c7e9a4/
# int16
# (478, 20)
# ../../cap2input/stage2/ed80c7303219ad3258cf8f21dd512a74/
# int16
# (481, 20)
# ../../cap2input/stage2/f76756cae862b3bd666fbb8a1d39b7b5/
# int16
# (343, 20)
# ../../cap2input/stage2/7985f80c2dcc95c899c16756a57f599b/
# uint16
# (443, 20)
# ../../cap2input/stage2/0171e54e4c0f68e8fc8c24523f71a86f/
# int16
# (135, 20)
# ../../cap2input/stage2/6bcccba7bff756dc12f5e9e4113c2a52/
# int16
# (334, 20)
# ../../cap2input/stage2/30d4b625a0901a6963e5fd7521aa6cfe/
# int16
# (563, 20)
# ../../cap2input/stage2/c640f21683d450142233e071a413aac1/
# int16
# (364, 20)
# ../../cap2input/stage2/6b640d7fb8fe9d165a500d354065e35c/
# int16
# (315, 20)
# 300
# ../../cap2input/stage2/9d454320c2e61b5e6f6e42161b4e8b2a/
# int16
# (361, 20)
# ../../cap2input/stage2/48826cf237182a40f0570950d20dc028/
# int16
# (397, 20)
# ../../cap2input/stage2/6451cbfc34c329168a1ecc5a103344fa/
# int16
# (478, 20)
# ../../cap2input/stage2/0b8afe447b5f1a2c405f41cf2fb1198e/
# int16
# (109, 20)
# ../../cap2input/stage2/ee1d1e2f942f06fe79bb445bdf6b5a1f/
# int16
# (319, 20)
# ../../cap2input/stage2/60f3a7a872f76dcde1ef5560ffd447d0/
# uint16
# (89, 20)
# ../../cap2input/stage2/1e09fb7be5eb41926f63aa3792220f9c/
# uint16
# (443, 20)
# ../../cap2input/stage2/b160e74183b009149c73c37db8e93f49/
# int16
# (334, 20)
# ../../cap2input/stage2/5514032473557df7a4a0d484d0ed27e5/
# uint16
# (527, 20)
# ../../cap2input/stage2/d0903b1b1dad1f885eebd07125d15d15/
# uint16
# (488, 20)
# ../../cap2input/stage2/87de7ae1cbcd60a3cc98684f03ff975b/
# int16
# (355, 20)
# ../../cap2input/stage2/97434189865e083f8f553e3a922b927a/
# int16
# (390, 20)
# ../../cap2input/stage2/20774c80e3115fdee3fb6d074dc90b34/
# int16
# (425, 20)
# ../../cap2input/stage2/ad677d927dbfdca141d5f5e990301867/
# int16
# (512, 20)
# ../../cap2input/stage2/ad9877d7153ba81280cf6fda3ec258ec/
# int16
# (333, 20)
# ../../cap2input/stage2/d128c15b1410d2f010922d68e7341266/
# int16
# (351, 20)
# ../../cap2input/stage2/e0ec2498c5d3676ad4fa2422108c088d/
# int16
# (425, 20)
# ../../cap2input/stage2/753ee50e96669a3e3321a360c4fca7d2/
# uint16
# (323, 20)
# ../../cap2input/stage2/5df13e26655687c40cfb724cffc27255/
# int16
# (521, 20)
# ../../cap2input/stage2/eb6e3cbc50852aa1d6dc51b8036287ec/
# int16
# (291, 20)
# ../../cap2input/stage2/99dabf11a7fa1a27f9fbac388b6bb7ce/
# int16
# (442, 20)
# ../../cap2input/stage2/9c5e14652bf76466fcfc0b4441efd00f/
# int16
# (346, 20)
# ../../cap2input/stage2/e8c8338b14a8b4e20e5de9a8ed7c79ac/
# int16
# (366, 20)
# ../../cap2input/stage2/91f3fef76618e660049ae92ccc78d68b/
# int16
# (397, 20)
# ../../cap2input/stage2/df74e431bf99c8d4e6a226b1b1cc91ac/
# int16
# (346, 20)
# ../../cap2input/stage2/3a957305fb7af2fbd696baf36b08c61b/
# int16
# (348, 20)
# ../../cap2input/stage2/0b116408fb03a40f5f6ade152d7d2d92/
# int16
# (280, 20)
# ../../cap2input/stage2/3d4b5c308499fc3add4ef36b2a1dc69f/
# uint16
# (408, 20)
# ../../cap2input/stage2/64234780b8febcc6b0971d7f0a2d58f8/
# uint16
# (331, 20)
# ../../cap2input/stage2/07625e01a28581f0d854cd53f9fd46ee/
# int16
# (397, 20)
# ../../cap2input/stage2/e7b1f83fd241891af1108c79efa9a123/
# int16
# (321, 20)
# ../../cap2input/stage2/2b2c9a1f94f2018e775c92d18d6ffa82/
# uint16
# (475, 20)
# ../../cap2input/stage2/e489786e381fcf8dd86b5c6956b5409c/
# uint16
# (515, 20)
# ../../cap2input/stage2/67f4d62ea7f7e49a49fb782488e67c78/
# int16
# (123, 20)
# ../../cap2input/stage2/592854c396488efd9b23a37cdae1b901/
# int16
# (346, 20)
# ../../cap2input/stage2/ff34734e135192a75838d18e870bec86/
# int16
# (475, 20)
# ../../cap2input/stage2/219a499a3a84da4368627bb353d0762e/
# int16
# (331, 20)
# ../../cap2input/stage2/52ec79ee345e5efefd44865e5f8b4933/
# int16
# (348, 20)
# ../../cap2input/stage2/f58388838d2f94a19988f2990fa7de8a/
# int16
# (98, 20)
# ../../cap2input/stage2/9cbf5ad2e8b00a9a8b4dece8e604243e/
# int16
# (364, 20)
# ../../cap2input/stage2/536a1c7233594edd31b78bcdb429e831/
# int16
# (457, 20)
# ../../cap2input/stage2/d16c163e209df73c1184ba197a4613cb/
# uint16
# (390, 20)
# ../../cap2input/stage2/3171f8f427b1879c859dd0aac9c8a684/
# int16
# (114, 20)
# ../../cap2input/stage2/0f5066ad16052f57aceebe9bfc248595/
# int16
# (121, 20)
# ../../cap2input/stage2/39263559a35c477050013c80085e0301/
# int16
# (457, 20)
# ../../cap2input/stage2/c5f3b3390e3f873360b8f91439e0f280/
# int16
# (307, 20)
# ../../cap2input/stage2/348357a1cfaaff752d5f2185cc1f8535/
# int16
# (343, 20)
# ../../cap2input/stage2/09c4e9f449f40508e399d692fd4f986b/
# int16
# (489, 20)
# ../../cap2input/stage2/e50e25554d4aad665f9ffbc7a6605a18/
# uint16
# (112, 20)
# ../../cap2input/stage2/d3294064936330c54261e02abf698c41/
# int16
# (313, 20)
# ../../cap2input/stage2/242bc4bee476ef1d7fae68b58605d468/
# int16
# (450, 20)
# ../../cap2input/stage2/f31e47d431624a0ea59b84de044ae55e/
# int16
# (300, 20)
# ../../cap2input/stage2/1695fee1f1dcac0094ddcd0c4a5d78a5/
# int16
# (108, 20)
# ../../cap2input/stage2/cd15cbbdb2b14177c48e7d300450b5be/
# int16
# (343, 20)
# ../../cap2input/stage2/8e419f7a45b6b7292d0b06a1980eb1b0/
# int16
# (279, 20)
# ../../cap2input/stage2/12656cf56654f1ae8e920856ac9fc97c/
# int16
# (109, 20)
# ../../cap2input/stage2/47781a7d9deecc7e4005ccbe6b023931/
# int16
# (321, 20)
# ../../cap2input/stage2/09d6f3fef2a3b280185de76601717d78/
# int16
# (331, 20)
# ../../cap2input/stage2/ac7493533e667b077b7180642fb1dc4d/
# int16
# (213, 20)
# ../../cap2input/stage2/7f1d2088b4244395b72eb8287f66a295/
# int16
# (337, 20)
# ../../cap2input/stage2/60c9ff5a174c41b84b9bf521045cb96e/
# int16
# (465, 20)
# ../../cap2input/stage2/734369ceaa05c956d165a9d7cfa84240/
# int16
# (318, 20)
# ../../cap2input/stage2/f96f703c496746f1610021121812e19e/
# int16
# (253, 20)
# ../../cap2input/stage2/a226ad784059cb82107a479bab21dedf/
# int16
# (502, 20)
# ../../cap2input/stage2/752ca005774c5f29fb4e89aa10176cd9/
# uint16
# (472, 20)
# ../../cap2input/stage2/275e08bb6724790a375876883c7eeb81/
# int16
# (337, 20)
# ../../cap2input/stage2/9417377a5aeb266804c605ab3b11c916/
# int16
# (348, 20)
# ../../cap2input/stage2/6f76555e8e65be4886e8868d7ba3f510/
# int16
# (381, 20)
# ../../cap2input/stage2/75c259b9ba8c64cb366a312a66b5b91b/
# int16
# (120, 20)
# ../../cap2input/stage2/395904459eb2402ab5b1ad22b666f931/
# int16
# (455, 20)
# ../../cap2input/stage2/0eb838fa78eeca9c4b67ea4d0d37a82f/
# int16
# (436, 20)
# ../../cap2input/stage2/555cf9806b55fa87450dc51e8e72d864/
# int16
# (487, 20)
# ../../cap2input/stage2/ba148739f58f8279f5a9ca018945ee0d/
# int16
# (378, 20)
# ../../cap2input/stage2/bd29aa956c349ab2a2b48a0ed34f8974/
# int16
# (373, 20)
# ../../cap2input/stage2/99f6e5341d25a934bbfb355e8ab021d0/
# int16
# (512, 20)
# ../../cap2input/stage2/e985b90eb33171a65abee8564aa1b4d5/
# int16
# (502, 20)
# ../../cap2input/stage2/1e5ac579c6aabb10ae85a614330c67de/
# int16
# (337, 20)
# ../../cap2input/stage2/3b4c610fce3d4d723bc17986395af9ab/
# int16
# (126, 20)
# ../../cap2input/stage2/6df93d1a93e1fd9754f0a4e5252e95b6/
# int16
# (484, 20)
# ../../cap2input/stage2/cfd49b344e7de2e5165b5cfb0b6c3c4e/
# int16
# (385, 20)
# ../../cap2input/stage2/c5048b20e33f27e18baa8bc94deef662/
# int16
# (564, 20)
# ../../cap2input/stage2/09aec51e845d17f2ec5459b5e292abb8/
# int16
# (264, 20)
# ../../cap2input/stage2/814cab8bde20e9e94250732cbc3e6d02/
# int16
# (559, 20)
# ../../cap2input/stage2/f83f942a23149ec80ee5287f864b1b17/
# int16
# (363, 20)
# ../../cap2input/stage2/9ee52b8505a56d048059d5d22d40b5ec/
# uint16
# (487, 20)
# ../../cap2input/stage2/8cf3958a0f44f1bd68da05028a562274/
# int16
# (115, 20)
# ../../cap2input/stage2/417e3c40213fe0b8474b1ff74318f14c/
# uint16
# (447, 20)
# ../../cap2input/stage2/346f914790572121aab4df2fc9d1dc42/
# int16
# (371, 20)
# ../../cap2input/stage2/764ce4a3ca12a16cd55ce00881019287/
# int16
# (367, 20)
# ../../cap2input/stage2/cd4f000784503503feb427133a49ca3a/
# int16
# (467, 20)
# ../../cap2input/stage2/36d352f118d3560d7f3bc100e26fe3fe/
# int16
# (349, 20)
# ../../cap2input/stage2/5b162effadb4b71d97cc48f0d3472d1f/
# int16
# (458, 20)
# ../../cap2input/stage2/7684fc6976d0e1acaeb3a9a5a7a5c7c7/
# int16
# (128, 20)
# ../../cap2input/stage2/d108d1b5be655ca0dfc811db8d244882/
# int16
# (324, 20)
# ../../cap2input/stage2/ee7d43a9c214c33d1ca97b6e8b62dfed/
# int16
# (419, 20)
# ../../cap2input/stage2/dfbc3ed94387313b0ad8e440d472097f/
# int16
# (343, 20)
# ../../cap2input/stage2/88e282ef02d78b43870095a0c4f3b2dd/
# int16
# (303, 20)
# ../../cap2input/stage2/2805ecbf568656eff77e968f27f55711/
# uint16
# (276, 20)
# ../../cap2input/stage2/e0d1d4262c05f725843a94a27138d418/
# uint16
# (539, 20)
# ../../cap2input/stage2/8e292f0453ad396f58287f0cf1c1a9ca/
# int16
# (551, 20)
# 400
# ../../cap2input/stage2/35a388aafa5fae8987968dfc4341ba0b/
# int16
# (334, 20)
# ../../cap2input/stage2/35972a9100f5290e53436a8249ecee26/
# int16
# (118, 20)
# ../../cap2input/stage2/3fd70f5fb05821229a4728c088139faf/
# int16
# (310, 20)
# ../../cap2input/stage2/9e041750951de329e7c7a20acdb9c88f/
# uint16
# (496, 20)
# ../../cap2input/stage2/db9c626391696ea11bb2522df6fd5fae/
# uint16
# (155, 20)
# ../../cap2input/stage2/c09b3be8e13dccda25ccff1c0abe7c45/
# uint16
# (403, 20)
# ../../cap2input/stage2/9adcfc94f68f4fcebb47a9c11c9b3d3e/
# uint16
# (472, 20)
# ../../cap2input/stage2/beab087d269c31273ccf5eb12d37739b/
# int16
# (397, 20)
# ../../cap2input/stage2/56c9eb5234b8f4c51c3a14d93a47e448/
# int16
# (426, 20)
# ../../cap2input/stage2/5ee14a528ac000b13ac64504048957e9/
# int16
# (315, 20)
# ../../cap2input/stage2/007c1246c5fe6f200378f6b91323dc2a/
# int16
# (411, 20)
# ../../cap2input/stage2/518bd9e72dd93f5e94b8a00bac60ef5e/
# uint16
# (452, 20)
# ../../cap2input/stage2/9fb26348e55b7b1b5247e59104beec5f/
# int16
# (330, 20)
# ../../cap2input/stage2/e4a5ab13581fc9decd0ce8cfed4d8ecb/
# int16
# (450, 20)
# ../../cap2input/stage2/0214c2ae7a8a922099f60f1f7f1b0027/
# int16
# (397, 20)
# ../../cap2input/stage2/5ff669224d56837c6e708071570f6bf8/
# int16
# (312, 20)
# ../../cap2input/stage2/b3b2241e2a7f6817886e7fb1578d305f/
# int16
# (334, 20)
# ../../cap2input/stage2/030d5e1a5dbe0600320ceb2a9ee35b13/
# int16
# (360, 20)
# ../../cap2input/stage2/94ecef909ae474ffd3337a15c62b30e0/
# int16
# (307, 20)
# ../../cap2input/stage2/c65c04ff2cab8677c509abc3d14615df/
# int16
# (437, 20)
# ../../cap2input/stage2/c4a4a83e2ebb159ba9f76249b32366dd/
# int16
# (116, 20)
# ../../cap2input/stage2/54a54b68703181af149c61b975c3c902/
# int16
# (343, 20)
# ../../cap2input/stage2/66733173c0dadfec25f8bb4efc1c2ccc/
# int16
# (338, 20)
# ../../cap2input/stage2/331a22ebf2241b692e0038ec43ceefd3/
# int16
# (147, 20)
# ../../cap2input/stage2/7d1ac3893774add9b340a7d35891261d/
# int16
# (518, 20)
# ../../cap2input/stage2/b03c8306ba45c37af605d765373bf391/
# int16
# (285, 20)
# ../../cap2input/stage2/ff910f590b8d19dbc135d69a4bb6dc3e/
# uint16
# (302, 20)
# ../../cap2input/stage2/eb58b7dd42911ddd20a118d9526a9fbb/
# int16
# (330, 20)
# ../../cap2input/stage2/a05dae5c271ef3048b80d22408bf0d4c/
# uint16
# (398, 20)
# ../../cap2input/stage2/db616050c543fcd0211920f4c98ea7d8/
# int16
# (336, 20)
# ../../cap2input/stage2/96c53b8f4795e8282883fcb73d1cf886/
# int16
# (281, 20)
# ../../cap2input/stage2/9836036213d8da1603008c1eb59d8f6b/
# int16
# (348, 20)
# ../../cap2input/stage2/a3f2886393c9c08419f2b139fed32293/
# int16
# (322, 20)
# ../../cap2input/stage2/58be3713625882c3ff526ea5e5de3faa/
# int16
# (121, 20)
# ../../cap2input/stage2/65d2f8aee03ee9e111e64856c3d5ef14/
# uint16
# (448, 20)
# ../../cap2input/stage2/3bffdbca42e100071266900c0fc448a2/
# int16
# (512, 20)
# ../../cap2input/stage2/b18322effc76a3327506ba9936535d99/
# int16
# (357, 20)
# ../../cap2input/stage2/951cb7ff32666ac91dd95968af53e3dc/
# uint16
# (467, 20)
# ../../cap2input/stage2/fc35b866ed1b3176193ccab251394cf2/
# int16
# (342, 20)
# ../../cap2input/stage2/fe4e8d77fa1770a331b3fca0f712d1a2/
# int16
# (316, 20)
# ../../cap2input/stage2/15df31b452c0c92bef1d60fd75a99df7/
# uint16
# (457, 20)
# ../../cap2input/stage2/dd3059f9f7293654b627ea5f124c59b9/
# int16
# (520, 20)
# ../../cap2input/stage2/976bf21011d3486bb9c76f2a271de186/
# uint16
# (448, 20)
# ../../cap2input/stage2/b04659303dbb3fa122036e85ddd11fbe/
# int16
# (481, 20)
# ../../cap2input/stage2/35625191fba75c5572eb304da36b044f/
# int16
# (352, 20)
# ../../cap2input/stage2/060e549637d08dd67050b0f27d56ba0b/
# int16
# (334, 20)
# ../../cap2input/stage2/7b034eb9bbe47e3bab530d4b54c28995/
# uint16
# (99, 20)
# ../../cap2input/stage2/a5b143d441469513096dabf6ca913197/
# uint16
# (458, 20)
# ../../cap2input/stage2/a9d414aeeef6981f32b857ebd1f3c91f/
# int16
# (361, 20)
# ../../cap2input/stage2/04f10322dd24edfaa7283e32b9bd6b30/
# uint16
# (449, 20)
# ../../cap2input/stage2/069ad419868921dda3ed47e23ecdd4f1/
# uint16
# (488, 20)
# ../../cap2input/stage2/385558bb252ebdfa36176dd595b3c740/
# int16
# (129, 20)
# ../../cap2input/stage2/aa070ed19af0fad480a807b75e0a816b/
# int16
# (470, 20)
# ../../cap2input/stage2/95c8c4d5bf5c2b01fcc8e9e06cb05419/
# int16
# (300, 20)
# ../../cap2input/stage2/fd43d08452687499c00dc62511e5fb8c/
# int16
# (397, 20)
# ../../cap2input/stage2/997db0c429de7f0bbf782ceb282ea010/
# uint16
# (147, 20)
# ../../cap2input/stage2/a966293e9872a02b8011e19219cd52a2/
# int16
# (320, 20)
# ../../cap2input/stage2/d4afc31053e58ffd55f6ee276a14569b/
# int16
# (324, 20)
# ../../cap2input/stage2/cf06fdc873958431873a3f6f9422e68c/
# int16
# (346, 20)
# ../../cap2input/stage2/7118040983d42e09835430d424347bb4/
# int16
# (340, 20)
# ../../cap2input/stage2/e7c15f23d6b22437895aff9027d2c5eb/
# int16
# (346, 20)
# ../../cap2input/stage2/fa8befbbf03c5539363996a576d5df20/
# int16
# (307, 20)
# ../../cap2input/stage2/5ee96643aa40a7c32405966489a5ad9d/
# uint16
# (469, 20)
# ../../cap2input/stage2/02aad899c461807ade5bde2ed3e61c09/
# uint16
# (462, 20)
# ../../cap2input/stage2/4e89f25452c29ce839596c9297452eac/
# int16
# (531, 20)
# ../../cap2input/stage2/cb7c09bf5f65597a074e9acfaba32ba3/
# uint16
# (474, 20)
# ../../cap2input/stage2/599c0715cafcd130381abdbc5e40187b/
# uint16
# (570, 20)
# ../../cap2input/stage2/3a35f023e17bd7f07c33f44021934655/
# int16
# (328, 20)
# ../../cap2input/stage2/0b922b907eeb8f02010c876f0c2efe26/
# uint16
# (521, 20)
# ../../cap2input/stage2/ce5415e5d0c3913ed55009e51e0f23d7/
# uint16
# (548, 20)
# ../../cap2input/stage2/c69b8fbe155444085faa2d8a77fa2077/
# uint16
# (87, 20)
# ../../cap2input/stage2/1c9a8b9ee193c5f967c6299e961e3dac/
# int16
# (504, 20)
# ../../cap2input/stage2/150473d0dfba5e809448fd9715b48644/
# int16
# (361, 20)
# ../../cap2input/stage2/4ccaa4579f598e1874301917ba11c897/
# int16
# (358, 20)
# ../../cap2input/stage2/b5b31a55495e2b822e5c42ccb1f54d27/
# int16
# (349, 20)
# ../../cap2input/stage2/49c2ceee1aa3abb4f6f01ceaf63fec9c/
# int16
# (324, 20)
# ../../cap2input/stage2/3b3bc0fb14c53f4e89b7ddd9a8153362/
# int16
# (369, 20)
# ../../cap2input/stage2/467fbaad4184bc2a030c27351549298f/
# int16
# (303, 20)
# ../../cap2input/stage2/e3f19803684a23af7ddba9ab706aeb6c/
# int16
# (307, 20)
# ../../cap2input/stage2/aa080347007854286314698113e398f8/
# uint16
# (494, 20)
# ../../cap2input/stage2/1e506f62fd2a6193ed0a3af1cbbbd5fd/
# int16
# (318, 20)
# ../../cap2input/stage2/37e90452caa5924546f33804040fc858/
# int16
# (334, 20)
# ../../cap2input/stage2/acad949d5d5df1a775bcfd6da032f226/
# int16
# (370, 20)
# ../../cap2input/stage2/fa39e1bdcb286b9161c867cd51d7bbbd/
# int16
# (474, 20)
# ../../cap2input/stage2/5883fb71691a1e32cde05d26578e9abc/
# int16
# (331, 20)
# ../../cap2input/stage2/c0a7764f92c01efde9aa6312250be3a4/
# int16
# (487, 20)
# ../../cap2input/stage2/598683dc697609e04de9b2aa5b03a9de/
# int16
# (367, 20)
# ../../cap2input/stage2/b9e5e3088d630ad8cb1b89966e394da2/
# int16
# (307, 20)
# ../../cap2input/stage2/e99078272c13ec179d8d9eb20a5789c5/
# int16
# (349, 20)
# ../../cap2input/stage2/2ed5f3e84445d6b48481f85594239ab2/
# uint16
# (425, 20)
# ../../cap2input/stage2/66dfced7056ab28e85423be7839d1d7d/
# uint16
# (481, 20)
# ../../cap2input/stage2/789503ce9fceedc4a7b21f939b40ed82/
# int16
# (456, 20)
# ../../cap2input/stage2/1ec3740d37c058058bf70949ba9e5766/
# int16
# (572, 20)
# ../../cap2input/stage2/647b7661f3f5178e7fdd132b6c287ecb/
# uint16
# (405, 20)
# ../../cap2input/stage2/8e67429799e9b385f9dde969aaded195/
# int16
# (344, 20)
# ../../cap2input/stage2/b824c3c5f6f85bd6502e7c14c42c6499/
# int16
# (367, 20)
# ../../cap2input/stage2/3e784909b0417eee6f1506fd2a9b7c5c/
# int16
# (348, 20)
# ../../cap2input/stage2/ae4bae7fb7dad1eacb965458d2dfd660/
# int16
# (131, 20)
# ../../cap2input/stage2/91b695914bf76d9672108290d7b9b8a0/
# int16
# (525, 20)
# ../../cap2input/stage2/c46981692786a307ccf1142256370f87/
# int16
# (113, 20)
# 500
# ../../cap2input/stage2/4d6dbd71a77bec1bde21b24e8171b531/
# int16
# (316, 20)
# ../../cap2input/stage2/6bcc733efe3176e8a81afb85a7d9a72c/
# int16
# (381, 20)
# ../../cap2input/stage2/1190a90df649a3b8266371f3bb2d4432/
# uint16
# (542, 20)
# ../../cap2input/stage2/071d08f7b19faf23606440d69d387b70/
# int16
# (319, 20)
# ../../cap2input/stage2/6fb3678448b49d53e05b655803d6a259/
# int16
# (328, 20)
# ../../cap2input/stage2/5c7c0d703fd2e11764285315e2b7f7fd/
# uint16
# (555, 20)
